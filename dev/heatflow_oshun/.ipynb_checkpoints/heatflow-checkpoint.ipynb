# %% [markdown]
# # Introduction
#
# The Fokker-Planck operator in OSHUN is fully non-linear for $f_0^0$ and linearized for $f_l^m$. The $f_l^m$ operator contains the effect of electron-ion collisions. Here, we validate the code by reproducing the heat-flow coefficient for heat-flow perpendicular to the magnetic field, $\kappa_\perp$, for various Z over a long gradient-scale-length. This offers a robust test of the $f_0, f_1$ equation set and its Fokker-Planck operator over a collisional time-scale.
#
# To calculate the heat flow coefficient, $\kappa_\perp$ for various ionization states, Z, and magnetic field strengths, a sinusoidal temperature profile is initialized. The simulations use one spatial direction, $\hat x$, and the magnetic field points in the $\hat z$ direction. The implicit electric field solver, and the implicit collision operators described in the Appendix, enable time-steps on the order of collision-times. Only one term in the spherical harmonic expansion is used (and required). $\kappa_\perp(Z)$ is calculated by dividing the gradient of the temperature by the heat flow, $q = (2/3) \pi \sum v^5 f_1^0 dv$. For the 1D cases studied here, $\kappa_\perp(Z)$, is in the $\hat x$ direction which is perpendicular to the applied magnetic field. We examine $\kappa_x(Z)=\kappa_\perp(Z)$ even when there is no magnetic field.

# %% [markdown]
# ### Import necessary modules for postprocessing

# %%
# %matplotlib inline
from IPython import display
from IPython.display import HTML

import sys
import time

import numpy as np
from matplotlib import pyplot as plt

import h5py
import oshunroutines as oshun
import heatflowroutines as heatflow
import re

# %% [markdown]
# ### Define some plotting routines
#
# _directory_ is the directory containing the output
#
# _Z_ is the ionization state

# %%
def get_kappa_sim_theo(directory, total_steps=200, start_steps=1):
    nu_ei = np.mean(heatflow.pullcompoundData(directory,'nuei', 0)[-1])
#     time, axes, kappa, _ = heatflow.getcompoundxt(directory,'kappa',np.array(range(start_steps, total_steps)))
    time, axes, kappa, kappaofxandt = heatflow.getcompoundxt(directory,'kappa',np.array(range(start_steps, total_steps)))

    for it in range(0,len(time)):
#     maxKvstime[it] = -Kofxandt[it,:].mean()
        kappa[it] = -kappaofxandt[it,:].mean()

#     time, axes, kappaEH, _ = heatflow.getcompoundxt(directory,'kappaEH',np.array(range(start_steps, total_steps)))
    time, axes, kappaEH, kappaEHofxandt = heatflow.getcompoundxt(directory,'kappaEH',np.array(range(start_steps, total_steps)))
    colltime = time * nu_ei
    return time, colltime, kappa, kappaEH

    
def plot_kappa(Z, *args, **kwargs):
    time, colltime, kappa, kappaEH = get_kappa_sim_theo(*args, **kwargs)
#     plt.rc('font', size=16)
    fig, ax1 = plt.subplots()
    ax2 = ax1.twiny()
    ax1.plot(time, kappa, time, kappaEH, '--')
#     ax1.plot()
    ax1.set_xlabel('Time ($\omega_0^{-1}$)')
    ax2.plot(colltime, kappa)
    ax2.set_xlabel(r'Time ($\nu_{ei}^{-1}$)', wrap=False)
    ax1.set_ylabel('$\kappa_\perp^c (nT\tau_{ei}/m_e)$')
#     ax2.cla()
    
    ax1.legend(['OSHUN', 'E-H, Z='+str(Z)])
    ax1.grid()
    plt.show()

# %% [markdown]
# ## Simulation setup
#
# For the following simulations, $n_0 = 10^{21} / \text{cm}^3,
# v_\text{th} = 0.07$ $c$. A sinusoidal temperature profile is imposed with $\Delta T / T_0 = 0.01$. The relevant collisional parameters such as the mean free path and collision frequency are found using the NRL formulary. A uniform profile of immobile ions provides a neutralizing background.
#
# Some care must be taken when discretizing the grids. When modeling such plasmas in OSHUN using the implicit field solver, one still needs to resolve the collision time, and to some extent, the collisional mean-free-path. In problems such as these, it is typically more intuitive to work in collisional units where the velocity is normalized by the thermal velocity, space normalized by the collisional mean-free-path, and time normalized by the collision time, i.e. $v_n = v/v_{th}, x_n = x/\lambda_{ei},t_n = t/\tau_{ei}$.
#
# Using this description, the gradient scale length can be quantified by $T/\nabla T = 1000 \lambda_{ei}$. A shallow temperature gradient ensures heat flow remains local. Since the collisional mean-free-path varies by $Z$, the size of the simulation domain is scaled to preserve the specified gradient scale length.

# %% [markdown]
# ### Run the Z=2 case
#
# The output has been provided in directory _Z2_. You can skipped this cell and look at the prepared results.

# %%
# !mkdir zarchis && \cp -f inputdeck.archis zarchis/inputdeck && cd zarchis && ln ../oshun.e . && ./oshun.e inputdeck
# Out:
# Initializing parallel environment ...     done
#
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 60
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 319.374 eV
# Corresponding thermal velocity        = 7.49481e+06 m/s
#
# Corresponding e-i log Lambda          = 3.37806
# Corresponding e-i collision frequency = 1.03233e+14 Hz
# Corresponding tau_e-i / tau_p         = 17.2768
# Corresponding e-i mean free path      = 0.0726013 microns
#
# Corresponding e-e log Lambda          = 5.58922
# Corresponding e-e collision frequency = 2.8467e+12 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 0.980392 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#
#  dt = 0.5 , Output #1
#  dt = 0.5 , Output #2
#  dt = 0.5 , Output #3
#  dt = 0.5 , Output #4
#  dt = 0.5 , Output #5
#  dt = 0.5 , Output #6
#  dt = 0.5 , Output #7
#  dt = 0.5 , Output #8
#  dt = 0.5 , Output #9
#  dt = 0.5 , Output #10
#  dt = 0.5 , Output #11
#  dt = 0.5 , Output #12
#  dt = 0.5 , Output #13
#  dt = 0.5 , Output #14
#  dt = 0.5 , Output #15
#  dt = 0.5 , Output #16
#  dt = 0.5 , Output #17
#  dt = 0.5 , Output #18
#  dt = 0.5 , Output #19
#  dt = 0.5 , Output #20
#  dt = 0.5 , Output #21
#  dt = 0.5 , Output #22
#  dt = 0.5 , Output #23
#  dt = 0.5 , Output #24
#  dt = 0.5 , Output #25
#  dt = 0.5 , Output #26
#  dt = 0.5 , Output #27
#  dt = 0.5 , Output #28
#  dt = 0.5 , Output #29
#  dt = 0.5 , Output #30
#  dt = 0.5 , Output #31
#  dt = 0.5 , Output #32
#  dt = 0.5 , Output #33
#  dt = 0.5 , Output #34
#  dt = 0.5 , Output #35
#  dt = 0.5 , Output #36
#  dt = 0.5 , Output #37
#  dt = 0.5 , Output #38
#  dt = 0.5 , Output #39
#  dt = 0.5 , Output #40
#  dt = 0.5 , Output #41
#  dt = 0.5 , Output #42
#  dt = 0.5 , Output #43
#  dt = 0.5 , Output #44
#  dt = 0.5 , Output #45
#  dt = 0.5 , Output #46
#  dt = 0.5 , Output #47
#  dt = 0.5 , Output #48
#  dt = 0.5 , Output #49
#  dt = 0.5 , Output #50
#  dt = 0.5 , Output #51
#  dt = 0.5 , Output #52
#  dt = 0.5 , Output #53
#  dt = 0.5 , Output #54
#  dt = 0.5 , Output #55
#  dt = 0.5 , Output #56
#  dt = 0.5 , Output #57
#  dt = 0.5 , Output #58
#  dt = 0.5 , Output #59
#  dt = 0.5 , Output #60
#  dt = 0.5 , Output #61
#  dt = 0.5 , Output #62
#  dt = 0.5 , Output #63
#  dt = 0.5 , Output #64
#  dt = 0.5 , Output #65
#  dt = 0.5 , Output #66
#  dt = 0.5 , Output #67
#  dt = 0.5 , Output #68
#  dt = 0.5 , Output #69
#  dt = 0.5 , Output #70
#  dt = 0.5 , Output #71
#  dt = 0.5 , Output #72
#  dt = 0.5 , Output #73
#  dt = 0.5 , Output #74
#  dt = 0.5 , Output #75
#  dt = 0.5 , Output #76
#  dt = 0.5 , Output #77
#  dt = 0.5 , Output #78
#  dt = 0.5 , Output #79
#  dt = 0.5 , Output #80
#  dt = 0.5 , Output #81
#  dt = 0.5 , Output #82
#  dt = 0.5 , Output #83
#  dt = 0.5 , Output #84
#  dt = 0.5 , Output #85
#  dt = 0.5 , Output #86
#  dt = 0.5 , Output #87
#  dt = 0.5 , Output #88
#  dt = 0.5 , Output #89
#  dt = 0.5 , Output #90
#  dt = 0.5 , Output #91
#  dt = 0.5 , Output #92
#  dt = 0.5 , Output #93
#  dt = 0.5 , Output #94
#  dt = 0.5 , Output #95
#  dt = 0.5 , Output #96
#  dt = 0.5 , Output #97
#  dt = 0.5 , Output #98
#  dt = 0.5 , Output #99
#  dt = 0.5 , Output #100
#  Dist Output #101
#
#  Big Dist Output #101
#
#  Restart Output #101
#
#  dt = 0.5 , Output #101
#  dt = 0.5 , Output #102
#  dt = 0.5 , Output #103
#  dt = 0.5 , Output #104
#  dt = 0.5 , Output #105
#  dt = 0.5 , Output #106
#  dt = 0.5 , Output #107
#  dt = 0.5 , Output #108
#  dt = 0.5 , Output #109
#  dt = 0.5 , Output #110
#  dt = 0.5 , Output #111
#  dt = 0.5 , Output #112
#  dt = 0.5 , Output #113
#  dt = 0.5 , Output #114
#  dt = 0.5 , Output #115
#  dt = 0.5 , Output #116
#  dt = 0.5 , Output #117
#  dt = 0.5 , Output #118
#  dt = 0.5 , Output #119
#  dt = 0.5 , Output #120
#  dt = 0.5 , Output #121
#  dt = 0.5 , Output #122
#  dt = 0.5 , Output #123
#  dt = 0.5 , Output #124
#  dt = 0.5 , Output #125
#  dt = 0.5 , Output #126
#  dt = 0.5 , Output #127
#  dt = 0.5 , Output #128
#  dt = 0.5 , Output #129
#  dt = 0.5 , Output #130
#  dt = 0.5 , Output #131
#  dt = 0.5 , Output #132
#  dt = 0.5 , Output #133
#  dt = 0.5 , Output #134
#  dt = 0.5 , Output #135
#  dt = 0.5 , Output #136
#  dt = 0.5 , Output #137
#  dt = 0.5 , Output #138
#  dt = 0.5 , Output #139
#  dt = 0.5 , Output #140
#  dt = 0.5 , Output #141
#  dt = 0.5 , Output #142
#  dt = 0.5 , Output #143
#  dt = 0.5 , Output #144
#  dt = 0.5 , Output #145
#  dt = 0.5 , Output #146
#  dt = 0.5 , Output #147
#  dt = 0.5 , Output #148
#  dt = 0.5 , Output #149
#  dt = 0.5 , Output #150
#  dt = 0.5 , Output #151
#  dt = 0.5 , Output #152
#  dt = 0.5 , Output #153
#  dt = 0.5 , Output #154
#  dt = 0.5 , Output #155
#  dt = 0.5 , Output #156
#  dt = 0.5 , Output #157
#  dt = 0.5 , Output #158
#  dt = 0.5 , Output #159
#  dt = 0.5 , Output #160
#  dt = 0.5 , Output #161
#  dt = 0.5 , Output #162
#  dt = 0.5 , Output #163
#  dt = 0.5 , Output #164
#  dt = 0.5 , Output #165
#  dt = 0.5 , Output #166
#  dt = 0.5 , Output #167
#  dt = 0.5 , Output #168
#  dt = 0.5 , Output #169
#  dt = 0.5 , Output #170
#  dt = 0.5 , Output #171
#  dt = 0.5 , Output #172
#  dt = 0.5 , Output #173
#  dt = 0.5 , Output #174
#  dt = 0.5 , Output #175
#  dt = 0.5 , Output #176
#  dt = 0.5 , Output #177
#  dt = 0.5 , Output #178
#  dt = 0.5 , Output #179
#  dt = 0.5 , Output #180
#  dt = 0.5 , Output #181
#  dt = 0.5 , Output #182
#  dt = 0.5 , Output #183
#  dt = 0.5 , Output #184
#  dt = 0.5 , Output #185
#  dt = 0.5 , Output #186
#  dt = 0.5 , Output #187
#  dt = 0.5 , Output #188
#  dt = 0.5 , Output #189
#  dt = 0.5 , Output #190
#  dt = 0.5 , Output #191
#  dt = 0.5 , Output #192
#  dt = 0.5 , Output #193
#  dt = 0.5 , Output #194
#  dt = 0.5 , Output #195
#  dt = 0.5 , Output #196
#  dt = 0.5 , Output #197
#  dt = 0.5 , Output #198
#  dt = 0.5 , Output #199
#  dt = 0.5 , Output #200Simulation took 4317 second(s).

# %%
# !mkdir zarchisv3 && \cp -f inputdeck.archisv3 zarchisv3/inputdeck && cd zarchisv3 && ln ../oshun.e . && ./oshun.e inputdeck
# Out:
# Initializing parallel environment ...     done
#
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 60
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 319.374 eV
# Corresponding thermal velocity        = 7.49481e+06 m/s
#
# Corresponding e-i log Lambda          = 3.37806
# Corresponding e-i collision frequency = 1.03233e+14 Hz
# Corresponding tau_e-i / tau_p         = 17.2768
# Corresponding e-i mean free path      = 0.0726013 microns
#
# Corresponding e-e log Lambda          = 5.58922
# Corresponding e-e collision frequency = 2.8467e+12 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 0.980392 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#
#  dt = 0.5 , Output #1
#  dt = 0.5 , Output #2
#  dt = 0.5 , Output #3
#  dt = 0.5 , Output #4
#  dt = 0.5 , Output #5
#  dt = 0.5 , Output #6
#  dt = 0.5 , Output #7
#  dt = 0.5 , Output #8
#  dt = 0.5 , Output #9
#  dt = 0.5 , Output #10
#  dt = 0.5 , Output #11
#  dt = 0.5 , Output #12
#  dt = 0.5 , Output #13
#  dt = 0.5 , Output #14
#  dt = 0.5 , Output #15
#  dt = 0.5 , Output #16
#  dt = 0.5 , Output #17
#  dt = 0.5 , Output #18
#  dt = 0.5 , Output #19
#  dt = 0.5 , Output #20
#  dt = 0.5 , Output #21
#  dt = 0.5 , Output #22
#  dt = 0.5 , Output #23
#  dt = 0.5 , Output #24
#  dt = 0.5 , Output #25
#  dt = 0.5 , Output #26
#  dt = 0.5 , Output #27
#  dt = 0.5 , Output #28
#  dt = 0.5 , Output #29
#  dt = 0.5 , Output #30
#  dt = 0.5 , Output #31
#  dt = 0.5 , Output #32
#  dt = 0.5 , Output #33
#  dt = 0.5 , Output #34
#  dt = 0.5 , Output #35
#  dt = 0.5 , Output #36
#  dt = 0.5 , Output #37
#  dt = 0.5 , Output #38
#  dt = 0.5 , Output #39
#  dt = 0.5 , Output #40
#  dt = 0.5 , Output #41
#  dt = 0.5 , Output #42
#  dt = 0.5 , Output #43
#  dt = 0.5 , Output #44
#  dt = 0.5 , Output #45
#  dt = 0.5 , Output #46
#  dt = 0.5 , Output #47
#  dt = 0.5 , Output #48
#  dt = 0.5 , Output #49
#  dt = 0.5 , Output #50
#  dt = 0.5 , Output #51
#  dt = 0.5 , Output #52
#  dt = 0.5 , Output #53
#  dt = 0.5 , Output #54
#  dt = 0.5 , Output #55
#  dt = 0.5 , Output #56
#  dt = 0.5 , Output #57
#  dt = 0.5 , Output #58
#  dt = 0.5 , Output #59
#  dt = 0.5 , Output #60
#  dt = 0.5 , Output #61
#  dt = 0.5 , Output #62
#  dt = 0.5 , Output #63
#  dt = 0.5 , Output #64
#  dt = 0.5 , Output #65
#  dt = 0.5 , Output #66
#  dt = 0.5 , Output #67
#  dt = 0.5 , Output #68
#  dt = 0.5 , Output #69
#  dt = 0.5 , Output #70
#  dt = 0.5 , Output #71
#  dt = 0.5 , Output #72
#  dt = 0.5 , Output #73
#  dt = 0.5 , Output #74
#  dt = 0.5 , Output #75
#  dt = 0.5 , Output #76
#  dt = 0.5 , Output #77
#  dt = 0.5 , Output #78
#  dt = 0.5 , Output #79
#  dt = 0.5 , Output #80
#  dt = 0.5 , Output #81
#  dt = 0.5 , Output #82
#  dt = 0.5 , Output #83
#  dt = 0.5 , Output #84
#  dt = 0.5 , Output #85
#  dt = 0.5 , Output #86
#  dt = 0.5 , Output #87
#  dt = 0.5 , Output #88
#  dt = 0.5 , Output #89
#  dt = 0.5 , Output #90
#  dt = 0.5 , Output #91
#  dt = 0.5 , Output #92
#  dt = 0.5 , Output #93
#  dt = 0.5 , Output #94
#  dt = 0.5 , Output #95
#  dt = 0.5 , Output #96
#  dt = 0.5 , Output #97
#  dt = 0.5 , Output #98
#  dt = 0.5 , Output #99
#  dt = 0.5 , Output #100
#  Dist Output #101
#
#  Big Dist Output #101
#
#  Restart Output #101
#
#  dt = 0.5 , Output #101
#  dt = 0.5 , Output #102
#  dt = 0.5 , Output #103
#  dt = 0.5 , Output #104
#  dt = 0.5 , Output #105
#  dt = 0.5 , Output #106
#  dt = 0.5 , Output #107
#  dt = 0.5 , Output #108
#  dt = 0.5 , Output #109
#  dt = 0.5 , Output #110
#  dt = 0.5 , Output #111
#  dt = 0.5 , Output #112
#  dt = 0.5 , Output #113
#  dt = 0.5 , Output #114
#  dt = 0.5 , Output #115
#  dt = 0.5 , Output #116
#  dt = 0.5 , Output #117
#  dt = 0.5 , Output #118
#  dt = 0.5 , Output #119
#  dt = 0.5 , Output #120
#  dt = 0.5 , Output #121
#  dt = 0.5 , Output #122
#  dt = 0.5 , Output #123
#  dt = 0.5 , Output #124
#  dt = 0.5 , Output #125
#  dt = 0.5 , Output #126
#  dt = 0.5 , Output #127
#  dt = 0.5 , Output #128
#  dt = 0.5 , Output #129
#  dt = 0.5 , Output #130
#  dt = 0.5 , Output #131
#  dt = 0.5 , Output #132
#  dt = 0.5 , Output #133
#  dt = 0.5 , Output #134
#  dt = 0.5 , Output #135
#  dt = 0.5 , Output #136
#  dt = 0.5 , Output #137
#  dt = 0.5 , Output #138
#  dt = 0.5 , Output #139
#  dt = 0.5 , Output #140
#  dt = 0.5 , Output #141
#  dt = 0.5 , Output #142
#  dt = 0.5 , Output #143
#  dt = 0.5 , Output #144
#  dt = 0.5 , Output #145
#  dt = 0.5 , Output #146
#  dt = 0.5 , Output #147
#  dt = 0.5 , Output #148
#  dt = 0.5 , Output #149
#  dt = 0.5 , Output #150
#  dt = 0.5 , Output #151
#  dt = 0.5 , Output #152
#  dt = 0.5 , Output #153
#  dt = 0.5 , Output #154
#  dt = 0.5 , Output #155
#  dt = 0.5 , Output #156
#  dt = 0.5 , Output #157
#  dt = 0.5 , Output #158
#  dt = 0.5 , Output #159
#  dt = 0.5 , Output #160
#  dt = 0.5 , Output #161
#  dt = 0.5 , Output #162
#  dt = 0.5 , Output #163
#  dt = 0.5 , Output #164
#  dt = 0.5 , Output #165
#  dt = 0.5 , Output #166
#  dt = 0.5 , Output #167
#  dt = 0.5 , Output #168
#  dt = 0.5 , Output #169
#  dt = 0.5 , Output #170
#  dt = 0.5 , Output #171
#  dt = 0.5 , Output #172
#  dt = 0.5 , Output #173
#  dt = 0.5 , Output #174
#  dt = 0.5 , Output #175
#  dt = 0.5 , Output #176
#  dt = 0.5 , Output #177
#  dt = 0.5 , Output #178
#  dt = 0.5 , Output #179
#  dt = 0.5 , Output #180
#  dt = 0.5 , Output #181
#  dt = 0.5 , Output #182
#  dt = 0.5 , Output #183
#  dt = 0.5 , Output #184
#  dt = 0.5 , Output #185
#  dt = 0.5 , Output #186
#  dt = 0.5 , Output #187
#  dt = 0.5 , Output #188
#  dt = 0.5 , Output #189
#  dt = 0.5 , Output #190
#  dt = 0.5 , Output #191
#  dt = 0.5 , Output #192
#  dt = 0.5 , Output #193
#  dt = 0.5 , Output #194
#  dt = 0.5 , Output #195
#  dt = 0.5 , Output #196
#  dt = 0.5 , Output #197
#  dt = 0.5 , Output #198
#  dt = 0.5 , Output #199
#  dt = 0.5 , Output #200Simulation took 2792 second(s).

# %%
# !mkdir Z2 && \cp -f inputdeck.z2 Z2/inputdeck && cd Z2 && ln ../oshun.e . && ./oshun.e inputdeck
# Out:
# Initializing parallel environment ...     done
#
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 2
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 2503.89 eV
# Corresponding thermal velocity        = 2.09855e+07 m/s
#
# Corresponding e-i log Lambda          = 7.64846
# Corresponding e-i collision frequency = 3.54918e+11 Hz
# Corresponding tau_e-i / tau_p         = 5025.17
# Corresponding e-i mean free path      = 59.1277 microns
#
# Corresponding e-e log Lambda          = 7.64846
# Corresponding e-e collision frequency = 1.77456e+11 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 400 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#
#  dt = 250 , Output #1
#  Big Dist Output #2
#
#  dt = 250 , Output #2
#  dt = 250 , Output #3
#  Dist Output #4
#
#  Big Dist Output #4
#
#  dt = 250 , Output #4
#  dt = 250 , Output #5
#  Big Dist Output #6
#
#  dt = 250 , Output #6
#  dt = 250 , Output #7
#  Dist Output #8
#
#  Big Dist Output #8
#
#  dt = 250 , Output #8
#  dt = 250 , Output #9
#  Big Dist Output #10
#
#  dt = 250 , Output #10
#  dt = 250 , Output #11
#  Dist Output #12
#
#  Big Dist Output #12
#
#  dt = 250 , Output #12
#  dt = 250 , Output #13
#  Big Dist Output #14
#
#  dt = 250 , Output #14
#  dt = 250 , Output #15
#  Dist Output #16
#
#  Big Dist Output #16
#
#  dt = 250 , Output #16
#  dt = 250 , Output #17
#  Big Dist Output #18
#
#  dt = 250 , Output #18
#  Restart Output #19
#
#  dt = 250 , Output #19
#  Dist Output #20
#
#  Big Dist Output #20
#
#  dt = 250 , Output #20
#  dt = 250 , Output #21
#  Big Dist Output #22
#
#  dt = 250 , Output #22
#  dt = 250 , Output #23
#  Dist Output #24
#
#  Big Dist Output #24
#
#  dt = 250 , Output #24
#  dt = 250 , Output #25
#  Big Dist Output #26
#
#  dt = 250 , Output #26
#  dt = 250 , Output #27
#  Dist Output #28
#
#  Big Dist Output #28
#
#  dt = 250 , Output #28
#  dt = 250 , Output #29
#  Big Dist Output #30
#
#  dt = 250 , Output #30
#  dt = 250 , Output #31
#  Dist Output #32
#
#  Big Dist Output #32
#
#  dt = 250 , Output #32
#  dt = 250 , Output #33
#  Big Dist Output #34
#
#  dt = 250 , Output #34
#  dt = 250 , Output #35
#  Dist Output #36
#
#  Big Dist Output #36
#
#  dt = 250 , Output #36
#  Restart Output #37
#
#  dt = 250 , Output #37
#  Big Dist Output #38
#
#  dt = 250 , Output #38
#  dt = 250 , Output #39
#  Dist Output #40
#
#  Big Dist Output #40
#
#  dt = 250 , Output #40
#  dt = 250 , Output #41
#  Big Dist Output #42
#
#  dt = 250 , Output #42
#  dt = 250 , Output #43
#  Dist Output #44
#
#  Big Dist Output #44
#
#  dt = 250 , Output #44
#  dt = 250 , Output #45
#  Big Dist Output #46
#
#  dt = 250 , Output #46
#  dt = 250 , Output #47
#  Dist Output #48
#
#  Big Dist Output #48
#
#  dt = 250 , Output #48
# ^C

# %%
# !mkdir Z2 && \cp -f inputdeck.z2 Z2/inputdeck && cd Z2 && ln ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck
# Out:
# 	Unloading the conflicting module 'intel/13.cs'
#
#
# The 'gcc/4.9.3' module is being loaded
#
# 	These modules were already loaded: ATS intel/17.0.1 idl/8.1 soxr/0.1.0 ffmpeg/1.1.1
#
# 	Unloading the conflicting module 'hdf5/1.8.18-shared'
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#      done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
# Warning: Folder 'restart' exists
# Warning: Folder 'output' exists
# Warning: Folder 'output/fields' exists
# Warning: Folder 'output/fields/EX' exists
# Warning: Folder 'output/fields/EY' exists
#
# Initializing parallel environment ...     done
#
# Warning: Folder 'output/fields/EZ' exists
# Warning: Folder 'output/fields/BX' exists
# Warning: Folder 'output/fields/BY' exists
# Warning: Folder 'output/fields/BZ' exists
# Warning: Folder 'output/moments' exists
# Warning: Folder 'output/moments/N' exists
# Warning: Folder 'output/moments/Jx' exists
# Warning: Folder 'output/moments/Jy' exists
# Warning: Folder 'output/moments/Jz' exists
# Warning: Folder 'output/moments/T' exists
# Warning: Folder 'output/moments/Qx' exists
# Warning: Folder 'output/moments/Qy' exists
# Warning: Folder 'output/moments/Qz' exists
# Warning: Folder 'output/moments/vNx' exists
# Warning: Folder 'output/moments/vNy' exists
# Warning: Folder 'output/moments/vNz' exists
# Warning: Folder 'output/moments/Z' exists
# Warning: Folder 'output/distributions' exists
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 2
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 2503.89 eV
# Corresponding thermal velocity        = 2.09855e+07 m/s
#
# Corresponding e-i log Lambda          = 7.64846
# Corresponding e-i collision frequency = 3.54918e+11 Hz
# Corresponding tau_e-i / tau_p         = 5025.17
# Corresponding e-i mean free path      = 59.1277 microns
#
# Corresponding e-e log Lambda          = 7.64846
# Corresponding e-e collision frequency = 1.77456e+11 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 400 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#
#  dt = 250 , Output #1
#  Big Dist Output #2
#
#  dt = 250 , Output #2
#  dt = 250 , Output #3
#  Dist Output #4
#
#  Big Dist Output #4
#
#  dt = 250 , Output #4
#  dt = 250 , Output #5
#  Big Dist Output #6
#
#  dt = 250 , Output #6
#  dt = 250 , Output #7
#  Dist Output #8
#
#  Big Dist Output #8
#
#  dt = 250 , Output #8
#  dt = 250 , Output #9
#  Big Dist Output #10
#
#  dt = 250 , Output #10
#  dt = 250 , Output #11
#  Dist Output #12
#
#  Big Dist Output #12
#
#  dt = 250 , Output #12
#  dt = 250 , Output #13
#  Big Dist Output #14
#
#  dt = 250 , Output #14
#  dt = 250 , Output #15
#  Dist Output #16
#
#  Big Dist Output #16
#
#  dt = 250 , Output #16
#  dt = 250 , Output #17
#  Big Dist Output #18
#
#  dt = 250 , Output #18
#  Restart Output #19
#
#  dt = 250 , Output #19
#  Dist Output #20
#
#  Big Dist Output #20
#
#  dt = 250 , Output #20
#  dt = 250 , Output #21
#  Big Dist Output #22
#
#  dt = 250 , Output #22
#  dt = 250 , Output #23
#  Dist Output #24
#
#  Big Dist Output #24
#
#  dt = 250 , Output #24
#  dt = 250 , Output #25
#  Big Dist Output #26
#
#  dt = 250 , Output #26
#  dt = 250 , Output #27
#  Dist Output #28
#
#  Big Dist Output #28
#
#  dt = 250 , Output #28
#  dt = 250 , Output #29
#  Big Dist Output #30
#
#  dt = 250 , Output #30
#  dt = 250 , Output #31
#  Dist Output #32
#
#  Big Dist Output #32
#
#  dt = 250 , Output #32
#  dt = 250 , Output #33
#  Big Dist Output #34
#
#  dt = 250 , Output #34
#  dt = 250 , Output #35
#  Dist Output #36
#
#  Big Dist Output #36
#
#  dt = 250 , Output #36
#  Restart Output #37
#
#  dt = 250 , Output #37
#  Big Dist Output #38
#
#  dt = 250 , Output #38
#  dt = 250 , Output #39
#  Dist Output #40
#
#  Big Dist Output #40
#
#  dt = 250 , Output #40
#  dt = 250 , Output #41
#  Big Dist Output #42
#
#  dt = 250 , Output #42
#  dt = 250 , Output #43
#  Dist Output #44
#
#  Big Dist Output #44
#
#  dt = 250 , Output #44
#  dt = 250 , Output #45
#  Big Dist Output #46
#
#  dt = 250 , Output #46
#  dt = 250 , Output #47
#  Dist Output #48
#
#  Big Dist Output #48
#
#  dt = 250 , Output #48
#  dt = 250 , Output #49
#  Big Dist Output #50
#
#  dt = 250 , Output #50
#  dt = 250 , Output #51
#  Dist Output #52
#
#  Big Dist Output #52
#
#  dt = 250 , Output #52
#  dt = 250 , Output #53
#  Big Dist Output #54
#
#  dt = 250 , Output #54
#  Restart Output #55
#
#  dt = 250 , Output #55
#  Dist Output #56
#
#  Big Dist Output #56
#
#  dt = 250 , Output #56
#  dt = 250 , Output #57
#  Big Dist Output #58
#
#  dt = 250 , Output #58
#  dt = 250 , Output #59
#  Dist Output #60
#
#  Big Dist Output #60
#
#  dt = 250 , Output #60
#  dt = 250 , Output #61
#  Big Dist Output #62
#
#  dt = 250 , Output #62
#  Dist Output #63
#
#  dt = 250 , Output #63
#  Big Dist Output #64
#
#  dt = 250 , Output #64
#  dt = 250 , Output #65
#  Big Dist Output #66
#
#  dt = 250 , Output #66
#  Dist Output #67
#
#  dt = 250 , Output #67
#  Big Dist Output #68
#
#  dt = 250 , Output #68
#  dt = 250 , Output #69
#  Big Dist Output #70
#
#  dt = 250 , Output #70
#  Dist Output #71
#
#  dt = 250 , Output #71
#  Big Dist Output #72
#
#  dt = 250 , Output #72
#  dt = 250 , Output #73
#  Restart Output #74
#
#  Big Dist Output #74
#
#  dt = 250 , Output #74
#  Dist Output #75
#
#  dt = 250 , Output #75
#  Big Dist Output #76
#
#  dt = 250 , Output #76
#  dt = 250 , Output #77
#  Big Dist Output #78
#
#  dt = 250 , Output #78
#  Dist Output #79
#
#  dt = 250 , Output #79
#  Big Dist Output #80
#
#  dt = 250 , Output #80
#  dt = 250 , Output #81
#  Big Dist Output #82
#
#  dt = 250 , Output #82
#  Dist Output #83
#
#  dt = 250 , Output #83
#  Big Dist Output #84
#
#  dt = 250 , Output #84
#  dt = 250 , Output #85
#  Big Dist Output #86
#
#  dt = 250 , Output #86
#  Dist Output #87
#
#  dt = 250 , Output #87
#  Big Dist Output #88
#
#  dt = 250 , Output #88
#  dt = 250 , Output #89
#  Big Dist Output #90
#
#  dt = 250 , Output #90
#  Dist Output #91
#
#  dt = 250 , Output #91
#  Restart Output #92
#
#  Big Dist Output #92
#
#  dt = 250 , Output #92
#  dt = 250 , Output #93
#  Big Dist Output #94
#
#  dt = 250 , Output #94
#  Dist Output #95
#
#  dt = 250 , Output #95
#  Big Dist Output #96
#
#  dt = 250 , Output #96
#  dt = 250 , Output #97
#  Big Dist Output #98
#
#  dt = 250 , Output #98
#  Dist Output #99
#
#  dt = 250 , Output #99
#  Big Dist Output #100
#
#  dt = 250 , Output #100
#  dt = 250 , Output #101
#  Big Dist Output #102
#
#  dt = 250 , Output #102
#  Dist Output #103
#
#  dt = 250 , Output #103
#  Big Dist Output #104
#
#  dt = 250 , Output #104
#  dt = 250 , Output #105
#  Big Dist Output #106
#
#  dt = 250 , Output #106
#  Dist Output #107
#
#  dt = 250 , Output #107
#  Big Dist Output #108
#
#  dt = 250 , Output #108
#  dt = 250 , Output #109
#  Big Dist Output #110
#
#  Restart Output #110
#
#  dt = 250 , Output #110
#  Dist Output #111
#
#  dt = 250 , Output #111
#  Big Dist Output #112
#
#  dt = 250 , Output #112
#  dt = 250 , Output #113
#  Big Dist Output #114
#
#  dt = 250 , Output #114
#  Dist Output #115
#
#  dt = 250 , Output #115
#  Big Dist Output #116
#
#  dt = 250 , Output #116
#  dt = 250 , Output #117
#  Big Dist Output #118
#
#  dt = 250 , Output #118
#  Dist Output #119
#
#  dt = 250 , Output #119
#  Big Dist Output #120
#
#  dt = 250 , Output #120
#  dt = 250 , Output #121
#  Big Dist Output #122
#
#  dt = 250 , Output #122
#  Dist Output #123
#
#  dt = 250 , Output #123
#  Big Dist Output #124
#
#  dt = 250 , Output #124
#  dt = 250 , Output #125
#  Big Dist Output #126
#
#  dt = 250 , Output #126
#  Dist Output #127
#
#  dt = 250 , Output #127
#  Big Dist Output #128
#
#  Restart Output #128
#
#  dt = 250 , Output #128
#  dt = 250 , Output #129
#  Big Dist Output #130
#
#  dt = 250 , Output #130
#  Dist Output #131
#
#  dt = 250 , Output #131
#  Big Dist Output #132
#
#  dt = 250 , Output #132
#  dt = 250 , Output #133
#  Big Dist Output #134
#
#  Dist Output #134
#
#  dt = 250 , Output #134
#  dt = 250 , Output #135
#  Big Dist Output #136
#
#  dt = 250 , Output #136
#  dt = 250 , Output #137
#  Big Dist Output #138
#
#  Dist Output #138
#
#  dt = 250 , Output #138
#  dt = 250 , Output #139
#  Big Dist Output #140
#
#  dt = 250 , Output #140
#  dt = 250 , Output #141
#  Big Dist Output #142
#
#  Dist Output #142
#
#  dt = 250 , Output #142
#  dt = 250 , Output #143
#  Big Dist Output #144
#
#  dt = 250 , Output #144
#  dt = 250 , Output #145
#  Big Dist Output #146
#
#  Dist Output #146
#
#  dt = 250 , Output #146
#  Restart Output #147
#
#  dt = 250 , Output #147
#  Big Dist Output #148
#
#  dt = 250 , Output #148
#  dt = 250 , Output #149
#  Big Dist Output #150
#
#  Dist Output #150
#
#  dt = 250 , Output #150
#  dt = 250 , Output #151
#  Big Dist Output #152
#
#  dt = 250 , Output #152
#  dt = 250 , Output #153
#  Big Dist Output #154
#
#  Dist Output #154
#
#  dt = 250 , Output #154
#  dt = 250 , Output #155
#  Big Dist Output #156
#
#  dt = 250 , Output #156
#  dt = 250 , Output #157
#  Big Dist Output #158
#
#  Dist Output #158
#
#  dt = 250 , Output #158
#  dt = 250 , Output #159
#  Big Dist Output #160
#
#  dt = 250 , Output #160
#  dt = 250 , Output #161
#  Big Dist Output #162
#
#  Dist Output #162
#
#  dt = 250 , Output #162
#  dt = 250 , Output #163
#  Big Dist Output #164
#
#  dt = 250 , Output #164
#  Restart Output #165
#
#  dt = 250 , Output #165
#  Big Dist Output #166
#
#  Dist Output #166
#
#  dt = 250 , Output #166
#  dt = 250 , Output #167
#  Big Dist Output #168
#
#  dt = 250 , Output #168
#  dt = 250 , Output #169
#  Big Dist Output #170
#
#  Dist Output #170
#
#  dt = 250 , Output #170
#  dt = 250 , Output #171
#  Big Dist Output #172
#
#  dt = 250 , Output #172
#  dt = 250 , Output #173
#  Big Dist Output #174
#
#  Dist Output #174
#
#  dt = 250 , Output #174
#  dt = 250 , Output #175
#  Big Dist Output #176
#
#  dt = 250 , Output #176
#  Big Dist Output #177
#
#  dt = 250 , Output #177
#  Dist Output #178
#
#  dt = 250 , Output #178
#  dt = 250 , Output #179
#  Big Dist Output #180
#
#  dt = 250 , Output #180
#  dt = 250 , Output #181
#  Big Dist Output #182
#
#  Dist Output #182
#
#  dt = 250 , Output #182
#  Restart Output #183
#
#  Big Dist Output #183
#
#  dt = 250 , Output #183
#  dt = 250 , Output #184
#  Big Dist Output #185
#
#  dt = 250 , Output #185
#  Dist Output #186
#
#  dt = 250 , Output #186
#  dt = 250 , Output #187
#  Big Dist Output #188
#
#  dt = 250 , Output #188
#  Big Dist Output #189
#
#  dt = 250 , Output #189
#  Dist Output #190
#
#  dt = 250 , Output #190
#  Big Dist Output #191
#
#  dt = 250 , Output #191
#  dt = 250 , Output #192
#  Dist Output #193
#
#  Big Dist Output #193
#
#  dt = 250 , Output #193
#  dt = 250 , Output #194
#  Big Dist Output #195
#
#  dt = 250 , Output #195
#  dt = 250 , Output #196
#  Dist Output #197
#
#  Big Dist Output #197
#
#  dt = 250 , Output #197
#  dt = 250 , Output #198
#  Big Dist Output #199
#
#  dt = 250 , Output #199
#  dt = 250 , Output #200Simulation took 295 second(s).

# %% [markdown]
# ## Plotting Fig. 3 (a)
#
# Let's plot heat-flow coefficient in an unmagnetized plasma as a function of time (blue solid line) for the Z=2 run. The dashed orange line corresponds to the steady-state value computed by Epperlein and Haines [Epperlein et. al., Phys. Fluids, **29**, 1029 (1986)].

# %%
plot_kappa(2, './old-dirs/Z2')

# %% [markdown]
# ### Run the Z=60 case
#
# The output has been provided in directory _Z60_. You can skipped this cell and look at the prepared results.

# %%
# !mkdir Z60 && \cp -f inputdeck.Z60t Z60/inputdeck && cd Z60 && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck
# Out:
# 	Unloading the conflicting module 'intel/13.cs'
#
#
# The 'gcc/4.9.3' module is being loaded
#
# 	These modules were already loaded: ATS intel/17.0.1 idl/8.1 soxr/0.1.0 ffmpeg/1.1.1
#
# 	Unloading the conflicting module 'hdf5/1.8.18-shared'
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 60
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 2503.89 eV
# Corresponding thermal velocity        = 2.09855e+07 m/s
#
# Corresponding e-i log Lambda          = 6.46692
# Corresponding e-i collision frequency = 9.0027e+12 Hz
# Corresponding tau_e-i / tau_p         = 198.11
# Corresponding e-i mean free path      = 2.33102 microns
#
# Corresponding e-e log Lambda          = 7.64846
# Corresponding e-e collision frequency = 1.77456e+11 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 75 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#
#  dt = 50 , Output #1
#  Big Dist Output #2
#
#  dt = 50 , Output #2
#  dt = 50 , Output #3
#  Dist Output #4
#
#  Big Dist Output #4
#
#  dt = 50 , Output #4
#  dt = 50 , Output #5
#  Big Dist Output #6
#
#  dt = 50 , Output #6
#  dt = 50 , Output #7
#  Dist Output #8
#
#  Big Dist Output #8
#
#  dt = 50 , Output #8
#  dt = 50 , Output #9
#  Big Dist Output #10
#
#  dt = 50 , Output #10
#  dt = 50 , Output #11
#  Dist Output #12
#
#  Big Dist Output #12
#
#  dt = 50 , Output #12
#  dt = 50 , Output #13
#  Big Dist Output #14
#
#  dt = 50 , Output #14
#  dt = 50 , Output #15
#  Dist Output #16
#
#  Big Dist Output #16
#
#  dt = 50 , Output #16
#  dt = 50 , Output #17
#  Big Dist Output #18
#
#  dt = 50 , Output #18
#  Restart Output #19
#
#  dt = 50 , Output #19
#  Dist Output #20
#
#  Big Dist Output #20
#
#  dt = 50 , Output #20
#  dt = 50 , Output #21
#  Big Dist Output #22
#
#  dt = 50 , Output #22
#  dt = 50 , Output #23
#  Dist Output #24
#
#  Big Dist Output #24
#
#  dt = 50 , Output #24
#  dt = 50 , Output #25
#  Big Dist Output #26
#
#  dt = 50 , Output #26
#  dt = 50 , Output #27
#  Dist Output #28
#
#  Big Dist Output #28
#
#  dt = 50 , Output #28
#  dt = 50 , Output #29
#  Big Dist Output #30
#
#  dt = 50 , Output #30
#  dt = 50 , Output #31
#  Dist Output #32
#
#  Big Dist Output #32
#
#  dt = 50 , Output #32
#  dt = 50 , Output #33
#  Big Dist Output #34
#
#  dt = 50 , Output #34
#  dt = 50 , Output #35
#  Dist Output #36
#
#  Big Dist Output #36
#
#  dt = 50 , Output #36
#  Restart Output #37
#
#  dt = 50 , Output #37
#  Big Dist Output #38
#
#  dt = 50 , Output #38
#  dt = 50 , Output #39
#  Dist Output #40
#
#  Big Dist Output #40
#
#  dt = 50 , Output #40
#  dt = 50 , Output #41
#  Big Dist Output #42
#
#  dt = 50 , Output #42
#  dt = 50 , Output #43
#  Dist Output #44
#
#  Big Dist Output #44
#
#  dt = 50 , Output #44
#  dt = 50 , Output #45
#  Big Dist Output #46
#
#  dt = 50 , Output #46
#  dt = 50 , Output #47
#  Dist Output #48
#
#  Big Dist Output #48
#
#  dt = 50 , Output #48
#  dt = 50 , Output #49
#  Big Dist Output #50
#
#  dt = 50 , Output #50
#  dt = 50 , Output #51
#  Dist Output #52
#
#  Big Dist Output #52
#
#  dt = 50 , Output #52
#  dt = 50 , Output #53
#  Big Dist Output #54
#
#  dt = 50 , Output #54
#  Restart Output #55
#
#  dt = 50 , Output #55
#  Dist Output #56
#
#  Big Dist Output #56
#
#  dt = 50 , Output #56
#  dt = 50 , Output #57
#  Big Dist Output #58
#
#  dt = 50 , Output #58
#  Dist Output #59
#
#  dt = 50 , Output #59
#  Big Dist Output #60
#
#  dt = 50 , Output #60
#  dt = 50 , Output #61
#  Big Dist Output #62
#
#  dt = 50 , Output #62
#  Dist Output #63
#
#  dt = 50 , Output #63
#  Big Dist Output #64
#
#  dt = 50 , Output #64
#  dt = 50 , Output #65
#  Big Dist Output #66
#
#  dt = 50 , Output #66
#  Dist Output #67
#
#  dt = 50 , Output #67
#  Big Dist Output #68
#
#  dt = 50 , Output #68
#  dt = 50 , Output #69
#  Big Dist Output #70
#
#  dt = 50 , Output #70
#  Dist Output #71
#
#  dt = 50 , Output #71
#  Big Dist Output #72
#
#  dt = 50 , Output #72
#  dt = 50 , Output #73
#  Restart Output #74
#
#  Big Dist Output #74
#
#  dt = 50 , Output #74
#  Dist Output #75
#
#  dt = 50 , Output #75
#  Big Dist Output #76
#
#  dt = 50 , Output #76
#  dt = 50 , Output #77
#  Big Dist Output #78
#
#  dt = 50 , Output #78
#  Dist Output #79
#
#  dt = 50 , Output #79
#  Big Dist Output #80
#
#  dt = 50 , Output #80
#  dt = 50 , Output #81
#  Big Dist Output #82
#
#  dt = 50 , Output #82
#  Dist Output #83
#
#  dt = 50 , Output #83
#  Big Dist Output #84
#
#  dt = 50 , Output #84
#  dt = 50 , Output #85
#  Big Dist Output #86
#
#  dt = 50 , Output #86
#  Dist Output #87
#
#  dt = 50 , Output #87
#  Big Dist Output #88
#
#  dt = 50 , Output #88
#  dt = 50 , Output #89
#  Big Dist Output #90
#
#  dt = 50 , Output #90
#  Dist Output #91
#
#  dt = 50 , Output #91
#  Restart Output #92
#
#  Big Dist Output #92
#
#  dt = 50 , Output #92
#  dt = 50 , Output #93
#  Big Dist Output #94
#
#  dt = 50 , Output #94
#  Dist Output #95
#
#  dt = 50 , Output #95
#  Big Dist Output #96
#
#  dt = 50 , Output #96
#  dt = 50 , Output #97
#  Big Dist Output #98
#
#  dt = 50 , Output #98
#  Dist Output #99
#
#  dt = 50 , Output #99
#  Big Dist Output #100
#
#  dt = 50 , Output #100
#  dt = 50 , Output #101
#  Big Dist Output #102
#
#  dt = 50 , Output #102
#  Dist Output #103
#
#  dt = 50 , Output #103
#  Big Dist Output #104
#
#  dt = 50 , Output #104
#  dt = 50 , Output #105
#  Big Dist Output #106
#
#  dt = 50 , Output #106
#  Dist Output #107
#
#  dt = 50 , Output #107
#  Big Dist Output #108
#
#  dt = 50 , Output #108
#  dt = 50 , Output #109
#  Big Dist Output #110
#
#  Restart Output #110
#
#  dt = 50 , Output #110
#  Dist Output #111
#
#  dt = 50 , Output #111
#  Big Dist Output #112
#
#  dt = 50 , Output #112
#  dt = 50 , Output #113
#  Big Dist Output #114
#
#  dt = 50 , Output #114
#  Dist Output #115
#
#  dt = 50 , Output #115
#  Big Dist Output #116
#
#  dt = 50 , Output #116
#  dt = 50 , Output #117
#  Big Dist Output #118
#
#  dt = 50 , Output #118
#  Dist Output #119
#
#  dt = 50 , Output #119
#  Big Dist Output #120
#
#  dt = 50 , Output #120
#  dt = 50 , Output #121
#  Big Dist Output #122
#
#  dt = 50 , Output #122
#  Dist Output #123
#
#  dt = 50 , Output #123
#  Big Dist Output #124
#
#  dt = 50 , Output #124
#  dt = 50 , Output #125
#  Big Dist Output #126
#
#  Dist Output #126
#
#  dt = 50 , Output #126
#  dt = 50 , Output #127
#  Big Dist Output #128
#
#  Restart Output #128
#
#  dt = 50 , Output #128
#  dt = 50 , Output #129
#  Big Dist Output #130
#
#  Dist Output #130
#
#  dt = 50 , Output #130
#  dt = 50 , Output #131
#  Big Dist Output #132
#  dt = 50 , Output #132
#  dt = 50 , Output #133
#  Big Dist Output #134
#
#  Dist Output #134
#
#  dt = 50 , Output #134
#  dt = 50 , Output #135
#  Big Dist Output #136
#
#  dt = 50 , Output #136
#  dt = 50 , Output #137
#  Big Dist Output #138
#
#  Dist Output #138
#
#  dt = 50 , Output #138
#  dt = 50 , Output #139
#  Big Dist Output #140
#
#  dt = 50 , Output #140
#  dt = 50 , Output #141
#  Big Dist Output #142
#
#  Dist Output #142
#
#  dt = 50 , Output #142
#  dt = 50 , Output #143
#  Big Dist Output #144
#
#  dt = 50 , Output #144
#  dt = 50 , Output #145
#  Big Dist Output #146
#
#  Dist Output #146
#
#  dt = 50 , Output #146
#  Restart Output #147
#
#  dt = 50 , Output #147
#  Big Dist Output #148
#
#  dt = 50 , Output #148
#  dt = 50 , Output #149
#  Big Dist Output #150
#
#  Dist Output #150
#
#  dt = 50 , Output #150
#  dt = 50 , Output #151
#  Big Dist Output #152
#
#  dt = 50 , Output #152
#  dt = 50 , Output #153
#  Big Dist Output #154
#
#  Dist Output #154
#
#  dt = 50 , Output #154
#  dt = 50 , Output #155
#  Big Dist Output #156
#
#  dt = 50 , Output #156
#  dt = 50 , Output #157
#  Big Dist Output #158
#
#  Dist Output #158
#
#  dt = 50 , Output #158
#  dt = 50 , Output #159
#  Big Dist Output #160
#
#  dt = 50 , Output #160
#  dt = 50 , Output #161
#  Big Dist Output #162
#
#  Dist Output #162
#
#  dt = 50 , Output #162
#  dt = 50 , Output #163
#  Big Dist Output #164
#
#  dt = 50 , Output #164
#  Restart Output #165
#
#  dt = 50 , Output #165
#  Big Dist Output #166
#
#  Dist Output #166
#
#  dt = 50 , Output #166
#  dt = 50 , Output #167
#  Big Dist Output #168
#
#  dt = 50 , Output #168
#  dt = 50 , Output #169
#  Big Dist Output #170
#
#  Dist Output #170
#
#  dt = 50 , Output #170
#  dt = 50 , Output #171
#  Big Dist Output #172
#
#  dt = 50 , Output #172
#  dt = 50 , Output #173
#  Big Dist Output #174
#
#  Dist Output #174
#
#  dt = 50 , Output #174
#  dt = 50 , Output #175
#  Big Dist Output #176
#
#  dt = 50 , Output #176
#  dt = 50 , Output #177
#  Big Dist Output #178
#
#  Dist Output #178
#
#  dt = 50 , Output #178
#  dt = 50 , Output #179
#  Big Dist Output #180
#
#  dt = 50 , Output #180
#  dt = 50 , Output #181
#  Big Dist Output #182
#
#  Dist Output #182
#
#  dt = 50 , Output #182
#  Restart Output #183
#
#  dt = 50 , Output #183
#  Big Dist Output #184
#
#  dt = 50 , Output #184
#  Big Dist Output #185
#
#  dt = 50 , Output #185
#  Dist Output #186
#
#  dt = 50 , Output #186
#  Big Dist Output #187
#
#  dt = 50 , Output #187
#  dt = 50 , Output #188
#  Big Dist Output #189
#
#  dt = 50 , Output #189
#  Dist Output #190
#
#  dt = 50 , Output #190
#  Big Dist Output #191
#
#  dt = 50 , Output #191
#  dt = 50 , Output #192
#  Dist Output #193
#
#  Big Dist Output #193
#
#  dt = 50 , Output #193
#  dt = 50 , Output #194
#  Big Dist Output #195
#
#  dt = 50 , Output #195
#  dt = 50 , Output #196
#  Dist Output #197
#
#  Big Dist Output #197
#
#  dt = 50 , Output #197
#  dt = 50 , Output #198
#  Big Dist Output #199
#
#  dt = 50 , Output #199
#  dt = 50 , Output #200Simulation took 344 second(s).

# %% [markdown]
# ## Plotting Fig. 3 (b)
#
# The blue solid line below shows the evolution of the heat-flow coefficient in an unmagnetized plasma. The dashed orange line the steady-state value computed by Epperlein and Haines [Epperlein et. al., Phys. Fluids, **29**, 1029 (1986)].

# %%
plot_kappa(60, './old-dirs/Z60')

# %% [markdown]
# ## The importance of including all terms in the $f_l^m$ collision operator for low Z simulations
#
# Simulations with $Z \lesssim 20$ require the full electron-electron collision operator (details in next paragraph) for greater accuracy. When the terms that form a tri-diagonal matrix in the collision operator are used (e.g., when $Z \gtrsim 20$), time-steps on the order of the collision time are possible. To recover the transport coefficient within $3\%$ for $Z \lesssim 20$, the terms describing the Rosenbluth potentials of $f_1^{0,1}$ are necessary.
#
# The linearized $f_l^m$ collision operator is reproduced in
# \begin{align}
# \begin{split}
# \frac{1}{Y_{ee}} \left(\frac{\delta f_l^m}{\delta t}\right) &= (8\pi f_0^0) f_l^m + \frac{(I_2 + J_{-1})}{3v} \frac{\partial^2 f_l^m}{\partial v^2} \\
# &+ \frac{(- I_2 + 2 J_{-1} + 3 I_0)}{3v^2} \frac{\partial f_l^m}{\partial v} \\
# &- \frac{l(l+1)}{2}\frac{(- I_2 + 2 J_{-1} + 3 I_0) + Y_{ei}/Y_{ee}}{3v^3} f_l^m \\
# &+ \left[A_1 \frac{1}{2v} \frac{\partial^2 f_0^0}{\partial v^2} + B_1 \frac{1}{v^2} \frac{\partial f_0^0}{\partial v}\right] I_{l+2}(f_l^m)  \\
# &+ \left[A_1 \frac{1}{2v} \frac{\partial^2 f_0^0}{\partial v^2} + B_2 \frac{1}{v^2} \frac{\partial f_0^0}{\partial v}\right] J_{-l-1}(f_l^m) \\
# &+ \left[A_2 \frac{1}{2v} \frac{\partial^2 f_0^0}{\partial v^2} + B_3 \frac{1}{v^2} \frac{\partial f_0^0}{\partial v}\right] I_{l}(f_l^m) \\
# &+ \left[A_2 \frac{1}{2v} \frac{\partial^2 f_0^0}{\partial v^2} + B_4 \frac{1}{v^2} \frac{\partial f_0^0}{\partial v}\right] J_{1-l}(f_l^m).
# \end{split}
# \end{align}
# where the coefficients $A_1,A_2,B_1,B_2,B_3,B_4$ are provided in Tzoufras et. al. $I_2(v), J_{-1}(v)$, and $I_0(v)$ are the Rosenbluth potentials of $f_0(v)$.
#
# The first four terms of the equation above are proportional to $f_l^m$ or its first or second derivatives. This enables the discretization of the first four terms implicitly, forming a tri-diagonal matrix. The last four terms describe the evolution of $f_l^m$ due to the interaction of it's own Rosenbluth potentials with $f_0$. Including these terms gives a dense matrix that is more computationally expensive to solve. It is recommended to include these terms as a check for low Z calculations where the off-diagonal terms describing electron-electron collisions have non-negligible contributions. In practice, we find that the tri-diagonal terms recover most calculations within $5-10\%$ as long as the discretization is carefully considered.
#
# The following cell will run 8 simulations, which will take a while. Here we are using $N_v$ values ($N_v=64$) lower than recommended for faster run time. Increasing $N_v$ would reduce the errors and get closer to the theoretical results.

# %%
# !mkdir z2 && cp inputdeck.z2 ./z2/inputdeck && cd z2 && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck

# !mkdir z2t && cp inputdeck.z2-tri ./z2t/inputdeck && cd z2t && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck

# !mkdir z20t && cp inputdeck.z20-tri ./z20t/inputdeck && cd z20t && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck

# !mkdir z20 && cp inputdeck.z20 ./z20/inputdeck && cd z20 && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck

# !mkdir z40 && cp inputdeck.z40 ./z40/inputdeck && cd z40 && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck

# !mkdir z40t && cp inputdeck.z40-tri ./z40t/inputdeck && cd z40t && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck

# !mkdir z60 && cp inputdeck.z40 ./z60/inputdeck && cd z60 && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck

# !mkdir z60t && cp inputdeck.z60-tri ./z60t/inputdeck && cd z60t && ln -s ../oshun.e . && mpirun -np 16 ./oshun.e inputdeck
# Out:
# 	Unloading the conflicting module 'intel/13.cs'
#
#
# The 'gcc/4.9.3' module is being loaded
#
# 	These modules were already loaded: ATS intel/17.0.1 idl/8.1 soxr/0.1.0 ffmpeg/1.1.1
#
# 	Unloading the conflicting module 'hdf5/1.8.18-shared'
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#      done
#
#      done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 40
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 2503.89 eV
# Corresponding thermal velocity        = 2.09855e+07 m/s
#
# Corresponding e-i log Lambda          = 6.87238
# Corresponding e-i collision frequency = 6.3781e+12 Hz
# Corresponding tau_e-i / tau_p         = 279.633
# Corresponding e-i mean free path      = 3.29024 microns
#
# Corresponding e-e log Lambda          = 7.64846
# Corresponding e-e collision frequency = 1.77456e+11 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 83.3333 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#
#  dt = 50 , Output #1
#  Big Dist Output #2
#
#  dt = 50 , Output #2
#  dt = 50 , Output #3
#  Dist Output #4
#
#  Big Dist Output #4
#
#  dt = 50 , Output #4
#  dt = 50 , Output #5
#  Big Dist Output #6
#
#  dt = 50 , Output #6
#  dt = 50 , Output #7
#  Dist Output #8
#
#  Big Dist Output #8
#
#  dt = 50 , Output #8
#  dt = 50 , Output #9
#  Big Dist Output #10
#
#  dt = 50 , Output #10
#  dt = 50 , Output #11
#  Dist Output #12
#
#  Big Dist Output #12
#
#  dt = 50 , Output #12
#  dt = 50 , Output #13
#  Big Dist Output #14
#
#  dt = 50 , Output #14
#  dt = 50 , Output #15
#  Dist Output #16
#
#  Big Dist Output #16
#
#  dt = 50 , Output #16
#  dt = 50 , Output #17
#  Big Dist Output #18
#
#  dt = 50 , Output #18
#  Restart Output #19
#
#  dt = 50 , Output #19
#  Dist Output #20
#
#  Big Dist Output #20
#
#  dt = 50 , Output #20
#  dt = 50 , Output #21
#  Big Dist Output #22
#
#  dt = 50 , Output #22
#  dt = 50 , Output #23
#  Dist Output #24
#
#  Big Dist Output #24
#
#  dt = 50 , Output #24
#  dt = 50 , Output #25
#  Big Dist Output #26
#
#  dt = 50 , Output #26
#  dt = 50 , Output #27
#  Dist Output #28
#
#  Big Dist Output #28
#
#  dt = 50 , Output #28
#  dt = 50 , Output #29
#  Big Dist Output #30
#
#  dt = 50 , Output #30
#  dt = 50 , Output #31
#  Dist Output #32
#
#  Big Dist Output #32
#
#  dt = 50 , Output #32
#  dt = 50 , Output #33
#  Big Dist Output #34
#
#  dt = 50 , Output #34
#  dt = 50 , Output #35
#  Dist Output #36
#
#  Big Dist Output #36
#
#  dt = 50 , Output #36
#  Restart Output #37
#
#  dt = 50 , Output #37
#  Big Dist Output #38
#
#  dt = 50 , Output #38
#  dt = 50 , Output #39
#  Dist Output #40
#
#  Big Dist Output #40
#
#  dt = 50 , Output #40
#  dt = 50 , Output #41
#  Big Dist Output #42
#
#  dt = 50 , Output #42
#  dt = 50 , Output #43
#  Dist Output #44
#
#  Big Dist Output #44
#
#  dt = 50 , Output #44
#  dt = 50 , Output #45
#  Big Dist Output #46
#
#  dt = 50 , Output #46
#  dt = 50 , Output #47
#  Dist Output #48
#
#  Big Dist Output #48
#
#  dt = 50 , Output #48
#  dt = 50 , Output #49
#  Big Dist Output #50
#
#  dt = 50 , Output #50
#  dt = 50 , Output #51
#  Dist Output #52
#
#  Big Dist Output #52
#
#  dt = 50 , Output #52
#  dt = 50 , Output #53
#  Big Dist Output #54
#
#  dt = 50 , Output #54
#  Restart Output #55
#
#  dt = 50 , Output #55
#  Dist Output #56
#
#  Big Dist Output #56
#
#  dt = 50 , Output #56
#  dt = 50 , Output #57
#  Big Dist Output #58
#
#  dt = 50 , Output #58
#  dt = 50 , Output #59
#  Dist Output #60
#
#  Big Dist Output #60
#
#  dt = 50 , Output #60
#  dt = 50 , Output #61
#  Big Dist Output #62
#
#  dt = 50 , Output #62
#  dt = 50 , Output #63
#  Dist Output #64
#
#  Big Dist Output #64
#
#  dt = 50 , Output #64
#  dt = 50 , Output #65
#  Big Dist Output #66
#
#  dt = 50 , Output #66
#  Dist Output #67
#
#  dt = 50 , Output #67
#  Big Dist Output #68
#
#  dt = 50 , Output #68
#  dt = 50 , Output #69
#  Big Dist Output #70
#
#  dt = 50 , Output #70
#  Dist Output #71
#
#  dt = 50 , Output #71
#  Big Dist Output #72
#
#  dt = 50 , Output #72
#  dt = 50 , Output #73
#  Restart Output #74
#
#  Big Dist Output #74
#
#  dt = 50 , Output #74
#  Dist Output #75
#
#  dt = 50 , Output #75
#  Big Dist Output #76
#
#  dt = 50 , Output #76
#  dt = 50 , Output #77
#  Big Dist Output #78
#
#  dt = 50 , Output #78
#  Dist Output #79
#
#  dt = 50 , Output #79
#  Big Dist Output #80
#
#  dt = 50 , Output #80
#  dt = 50 , Output #81
#  Big Dist Output #82
#
#  dt = 50 , Output #82
#  Dist Output #83
#
#  dt = 50 , Output #83
#  Big Dist Output #84
#
#  dt = 50 , Output #84
#  dt = 50 , Output #85
#  Big Dist Output #86
#
#  dt = 50 , Output #86
#  Dist Output #87
#
#  dt = 50 , Output #87
#  Big Dist Output #88
#
#  dt = 50 , Output #88
#  dt = 50 , Output #89
#  Big Dist Output #90
#
#  dt = 50 , Output #90
#  Dist Output #91
#
#  dt = 50 , Output #91
#  Restart Output #92
#
#  Big Dist Output #92
#
#  dt = 50 , Output #92
#  dt = 50 , Output #93
#  Big Dist Output #94
#
#  dt = 50 , Output #94
#  Dist Output #95
#
#  dt = 50 , Output #95
#  Big Dist Output #96
#
#  dt = 50 , Output #96
#  dt = 50 , Output #97
#  Big Dist Output #98
#
#  dt = 50 , Output #98
#  Dist Output #99
#
#  dt = 50 , Output #99
#  Big Dist Output #100
#
#  dt = 50 , Output #100
#  dt = 50 , Output #101
#  Big Dist Output #102
#
#  dt = 50 , Output #102
#  Dist Output #103
#
#  dt = 50 , Output #103
#  Big Dist Output #104
#
#  dt = 50 , Output #104
#  dt = 50 , Output #105
#  Big Dist Output #106
#
#  dt = 50 , Output #106
#  Dist Output #107
#
#  dt = 50 , Output #107
#  Big Dist Output #108
#
#  dt = 50 , Output #108
#  dt = 50 , Output #109
#  Big Dist Output #110
#
#  Restart Output #110
#
#  dt = 50 , Output #110
#  Dist Output #111
#
#  dt = 50 , Output #111
#  Big Dist Output #112
#
#  dt = 50 , Output #112
#  dt = 50 , Output #113
#  Big Dist Output #114
#
#  dt = 50 , Output #114
#  Dist Output #115
#
#  dt = 50 , Output #115
#  Big Dist Output #116
#
#  dt = 50 , Output #116
#  dt = 50 , Output #117
#  Big Dist Output #118
#
#  dt = 50 , Output #118
#  Dist Output #119
#
#  dt = 50 , Output #119
#  Big Dist Output #120
#
#  dt = 50 , Output #120
#  dt = 50 , Output #121
#  Big Dist Output #122
#
#  dt = 50 , Output #122
#  Dist Output #123
#
#  dt = 50 , Output #123
#  Big Dist Output #124
#
#  dt = 50 , Output #124
#  dt = 50 , Output #125
#  Big Dist Output #126
#
#  dt = 50 , Output #126
#  Dist Output #127
#
#  dt = 50 , Output #127
#  Big Dist Output #128
#
#  Restart Output #128
#
#  dt = 50 , Output #128
#  dt = 50 , Output #129
#  Big Dist Output #130
#
#  dt = 50 , Output #130
#  Dist Output #131
#
#  dt = 50 , Output #131
#  Big Dist Output #132
#  dt = 50 , Output #132
#  dt = 50 , Output #133
#  Big Dist Output #134
#
#  Dist Output #134
#
#  dt = 50 , Output #134
#  dt = 50 , Output #135
#  Big Dist Output #136
#
#  dt = 50 , Output #136
#  dt = 50 , Output #137
#  Big Dist Output #138
#
#  Dist Output #138
#
#  dt = 50 , Output #138
#  dt = 50 , Output #139
#  Big Dist Output #140
#
#  dt = 50 , Output #140
#  dt = 50 , Output #141
#  Big Dist Output #142
#
#  Dist Output #142
#
#  dt = 50 , Output #142
#  dt = 50 , Output #143
#  Big Dist Output #144
#
#  dt = 50 , Output #144
#  dt = 50 , Output #145
#  Big Dist Output #146
#
#  Dist Output #146
#
#  dt = 50 , Output #146
#  Restart Output #147
#
#  dt = 50 , Output #147
#  Big Dist Output #148
#
#  dt = 50 , Output #148
#  dt = 50 , Output #149
#  Big Dist Output #150
#
#  Dist Output #150
#
#  dt = 50 , Output #150
#  dt = 50 , Output #151
#  Big Dist Output #152
#
#  dt = 50 , Output #152
#  dt = 50 , Output #153
#  Big Dist Output #154
#
#  Dist Output #154
#
#  dt = 50 , Output #154
#  dt = 50 , Output #155
#  Big Dist Output #156
#
#  dt = 50 , Output #156
#  dt = 50 , Output #157
#  Big Dist Output #158
#
#  Dist Output #158
#
#  dt = 50 , Output #158
#  dt = 50 , Output #159
#  Big Dist Output #160
#
#  dt = 50 , Output #160
#  dt = 50 , Output #161
#  Big Dist Output #162
#
#  Dist Output #162
#
#  dt = 50 , Output #162
#  dt = 50 , Output #163
#  Big Dist Output #164
#
#  dt = 50 , Output #164
#  Restart Output #165
#
#  dt = 50 , Output #165
#  Big Dist Output #166
#
#  Dist Output #166
#
#  dt = 50 , Output #166
#  dt = 50 , Output #167
#  Big Dist Output #168
#
#  dt = 50 , Output #168
#  dt = 50 , Output #169
#  Big Dist Output #170
#
#  Dist Output #170
#
#  dt = 50 , Output #170
#  dt = 50 , Output #171
#  Big Dist Output #172
#
#  dt = 50 , Output #172
#  dt = 50 , Output #173
#  Big Dist Output #174
#
#  Dist Output #174
#
#  dt = 50 , Output #174
#  dt = 50 , Output #175
#  Big Dist Output #176
#
#  dt = 50 , Output #176
#  dt = 50 , Output #177
#  Big Dist Output #178
#
#  Dist Output #178
#
#  dt = 50 , Output #178
#  dt = 50 , Output #179
#  Big Dist Output #180
#
#  dt = 50 , Output #180
#  dt = 50 , Output #181
#  Big Dist Output #182
#
#  Dist Output #182
#
#  dt = 50 , Output #182
#  Restart Output #183
#
#  dt = 50 , Output #183
#  Big Dist Output #184
#
#  dt = 50 , Output #184
#  dt = 50 , Output #185
#  Big Dist Output #186
#
#  Dist Output #186
#
#  dt = 50 , Output #186
#  dt = 50 , Output #187
#  Big Dist Output #188
#
#  dt = 50 , Output #188
#  dt = 50 , Output #189
#  Big Dist Output #190
#
#  Dist Output #190
#
#  dt = 50 , Output #190
#  Big Dist Output #191
#
#  dt = 50 , Output #191
#  dt = 50 , Output #192
#  Big Dist Output #193
#
#  dt = 50 , Output #193
#  Dist Output #194
#
#  dt = 50 , Output #194
#  Big Dist Output #195
#
#  dt = 50 , Output #195
#  dt = 50 , Output #196
#  Dist Output #197
#
#  Big Dist Output #197
#
#  dt = 50 , Output #197
#  dt = 50 , Output #198
#  Big Dist Output #199
#
#  dt = 50 , Output #199
#  dt = 50 , Output #200Simulation took 379 second(s).
# 	Unloading the conflicting module 'intel/13.cs'
#
#
# The 'gcc/4.9.3' module is being loaded
#
# 	These modules were already loaded: ATS intel/17.0.1 idl/8.1 soxr/0.1.0 ffmpeg/1.1.1
#
# 	Unloading the conflicting module 'hdf5/1.8.18-shared'
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#      done
#
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 40
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 2503.89 eV
# Corresponding thermal velocity        = 2.09855e+07 m/s
#
# Corresponding e-i log Lambda          = 6.87238
# Corresponding e-i collision frequency = 6.3781e+12 Hz
# Corresponding tau_e-i / tau_p         = 279.633
# Corresponding e-i mean free path      = 3.29024 microns
#
# Corresponding e-e log Lambda          = 7.64846
# Corresponding e-e collision frequency = 1.77456e+11 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 112.5 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#
#  dt = 75 , Output #1
#  Big Dist Output #2
#
#  dt = 75 , Output #2
#  dt = 75 , Output #3
#  Dist Output #4
#
#  Big Dist Output #4
#
#  dt = 75 , Output #4
#  dt = 75 , Output #5
#  Big Dist Output #6
#
#  dt = 75 , Output #6
#  dt = 75 , Output #7
#  Dist Output #8
#
#  Big Dist Output #8
#
#  dt = 75 , Output #8
#  dt = 75 , Output #9
#  Big Dist Output #10
#
#  dt = 75 , Output #10
#  dt = 75 , Output #11
#  Dist Output #12
#
#  Big Dist Output #12
#
#  dt = 75 , Output #12
#  dt = 75 , Output #13
#  Big Dist Output #14
#
#  dt = 75 , Output #14
#  dt = 75 , Output #15
#  Dist Output #16
#
#  Big Dist Output #16
#
#  dt = 75 , Output #16
#  dt = 75 , Output #17
#  Big Dist Output #18
#
#  dt = 75 , Output #18
#  Restart Output #19
#
#  dt = 75 , Output #19
#  Dist Output #20
#
#  Big Dist Output #20
#
#  dt = 75 , Output #20
#  dt = 75 , Output #21
#  Big Dist Output #22
#
#  dt = 75 , Output #22
#  dt = 75 , Output #23
#  Dist Output #24
#
#  Big Dist Output #24
#
#  dt = 75 , Output #24
#  dt = 75 , Output #25
#  Big Dist Output #26
#
#  dt = 75 , Output #26
#  dt = 75 , Output #27
#  Dist Output #28
#
#  Big Dist Output #28
#
#  dt = 75 , Output #28
#  dt = 75 , Output #29
#  Big Dist Output #30
#
#  dt = 75 , Output #30
#  dt = 75 , Output #31
#  Dist Output #32
#
#  Big Dist Output #32
#
#  dt = 75 , Output #32
#  dt = 75 , Output #33
#  Big Dist Output #34
#
#  dt = 75 , Output #34
#  dt = 75 , Output #35
#  Dist Output #36
#
#  Big Dist Output #36
#
#  dt = 75 , Output #36
#  Restart Output #37
#
#  dt = 75 , Output #37
#  Big Dist Output #38
#
#  dt = 75 , Output #38
#  dt = 75 , Output #39
#  Dist Output #40
#
#  Big Dist Output #40
#
#  dt = 75 , Output #40
#  dt = 75 , Output #41
#  Big Dist Output #42
#
#  dt = 75 , Output #42
#  dt = 75 , Output #43
#  Dist Output #44
#
#  Big Dist Output #44
#
#  dt = 75 , Output #44
#  dt = 75 , Output #45
#  Big Dist Output #46
#
#  dt = 75 , Output #46
#  dt = 75 , Output #47
#  Dist Output #48
#
#  Big Dist Output #48
#
#  dt = 75 , Output #48
#  dt = 75 , Output #49
#  Big Dist Output #50
#
#  dt = 75 , Output #50
#  dt = 75 , Output #51
#  Dist Output #52
#
#  Big Dist Output #52
#
#  dt = 75 , Output #52
#  dt = 75 , Output #53
#  Big Dist Output #54
#
#  dt = 75 , Output #54
#  Restart Output #55
#
#  dt = 75 , Output #55
#  Dist Output #56
#
#  Big Dist Output #56
#
#  dt = 75 , Output #56
#  dt = 75 , Output #57
#  Big Dist Output #58
#
#  dt = 75 , Output #58
#  Dist Output #59
#
#  dt = 75 , Output #59
#  Big Dist Output #60
#
#  dt = 75 , Output #60
#  dt = 75 , Output #61
#  Big Dist Output #62
#  dt = 75 , Output #62
#  Dist Output #63
#
#  dt = 75 , Output #63
#  Big Dist Output #64
#
#  dt = 75 , Output #64
#  dt = 75 , Output #65
#  Big Dist Output #66
#
#  dt = 75 , Output #66
#  Dist Output #67
#
#  dt = 75 , Output #67
#  Big Dist Output #68
#
#  dt = 75 , Output #68
#  dt = 75 , Output #69
#  Big Dist Output #70
#
#  dt = 75 , Output #70
#  Dist Output #71
#
#  dt = 75 , Output #71
#  Big Dist Output #72
#
#  dt = 75 , Output #72
#  dt = 75 , Output #73
#  Restart Output #74
#
#  Big Dist Output #74
#
#  dt = 75 , Output #74
#  Dist Output #75
#
#  dt = 75 , Output #75
#  Big Dist Output #76
#
#  dt = 75 , Output #76
#  dt = 75 , Output #77
#  Big Dist Output #78
#
#  dt = 75 , Output #78
#  Dist Output #79
#
#  dt = 75 , Output #79
#  Big Dist Output #80
#
#  dt = 75 , Output #80
#  dt = 75 , Output #81
#  Big Dist Output #82
#
#  dt = 75 , Output #82
#  Dist Output #83
#
#  dt = 75 , Output #83
#  Big Dist Output #84
#
#  dt = 75 , Output #84
#  dt = 75 , Output #85
#  Big Dist Output #86
#
#  dt = 75 , Output #86
#  Dist Output #87
#
#  dt = 75 , Output #87
#  Big Dist Output #88
#
#  dt = 75 , Output #88
#  dt = 75 , Output #89
#  Big Dist Output #90
#
#  dt = 75 , Output #90
#  Dist Output #91
#
#  dt = 75 , Output #91
#  Restart Output #92
#
#  Big Dist Output #92
#
#  dt = 75 , Output #92
#  dt = 75 , Output #93
#  Big Dist Output #94
#
#  dt = 75 , Output #94
#  Dist Output #95
#
#  dt = 75 , Output #95
#  Big Dist Output #96
#
#  dt = 75 , Output #96
#  dt = 75 , Output #97
#  Big Dist Output #98
#
#  dt = 75 , Output #98
#  Dist Output #99
#
#  dt = 75 , Output #99
#  Big Dist Output #100
#
#  dt = 75 , Output #100
#  dt = 75 , Output #101
#  Big Dist Output #102
#
#  dt = 75 , Output #102
#  Dist Output #103
#
#  dt = 75 , Output #103
#  Big Dist Output #104
#
#  dt = 75 , Output #104
#  dt = 75 , Output #105
#  Big Dist Output #106
#
#  dt = 75 , Output #106
#  Dist Output #107
#
#  dt = 75 , Output #107
#  Big Dist Output #108
#
#  dt = 75 , Output #108
#  dt = 75 , Output #109
#  Big Dist Output #110
#
#  Restart Output #110
#
#  dt = 75 , Output #110
#  Dist Output #111
#
#  dt = 75 , Output #111
#  Big Dist Output #112
#
#  dt = 75 , Output #112
#  dt = 75 , Output #113
#  Big Dist Output #114
#
#  dt = 75 , Output #114
#  Dist Output #115
#
#  dt = 75 , Output #115
#  Big Dist Output #116
#
#  dt = 75 , Output #116
#  dt = 75 , Output #117
#  Big Dist Output #118
#
#  dt = 75 , Output #118
#  Dist Output #119
#
#  dt = 75 , Output #119
#  Big Dist Output #120
#
#  dt = 75 , Output #120
#  dt = 75 , Output #121
#  Big Dist Output #122
#
#  dt = 75 , Output #122
#  Dist Output #123
#
#  dt = 75 , Output #123
#  Big Dist Output #124
#
#  dt = 75 , Output #124
#  dt = 75 , Output #125
#  Big Dist Output #126
#
#  Dist Output #126
#
#  dt = 75 , Output #126
#  dt = 75 , Output #127
#  Big Dist Output #128
#
#  Restart Output #128
#
#  dt = 75 , Output #128
#  dt = 75 , Output #129
#  Big Dist Output #130
#
#  Dist Output #130
#
#  dt = 75 , Output #130
#  dt = 75 , Output #131
#  Big Dist Output #132
#
#  dt = 75 , Output #132
#  dt = 75 , Output #133
#  Big Dist Output #134
#
#  Dist Output #134
#
#  dt = 75 , Output #134
#  dt = 75 , Output #135
#  Big Dist Output #136
#
#  dt = 75 , Output #136
#  dt = 75 , Output #137
#  Big Dist Output #138
#
#  Dist Output #138
#
#  dt = 75 , Output #138
#  dt = 75 , Output #139
#  Big Dist Output #140
#
#  dt = 75 , Output #140
#  dt = 75 , Output #141
#  Big Dist Output #142
#
#  Dist Output #142
#
#  dt = 75 , Output #142
#  dt = 75 , Output #143
#  Big Dist Output #144
#
#  dt = 75 , Output #144
#  dt = 75 , Output #145
#  Big Dist Output #146
#
#  Dist Output #146
#
#  dt = 75 , Output #146
#  Restart Output #147
#
#  dt = 75 , Output #147
#  Big Dist Output #148
#
#  dt = 75 , Output #148
#  dt = 75 , Output #149
#  Big Dist Output #150
#
#  Dist Output #150
#
#  dt = 75 , Output #150
#  dt = 75 , Output #151
#  Big Dist Output #152
#
#  dt = 75 , Output #152
#  dt = 75 , Output #153
#  Big Dist Output #154
#
#  Dist Output #154
#
#  dt = 75 , Output #154
#  dt = 75 , Output #155
#  Big Dist Output #156
#
#  dt = 75 , Output #156
#  dt = 75 , Output #157
#  Big Dist Output #158
#
#  Dist Output #158
#
#  dt = 75 , Output #158
#  dt = 75 , Output #159
#  Big Dist Output #160
#
#  dt = 75 , Output #160
#  dt = 75 , Output #161
#  Big Dist Output #162
#
#  Dist Output #162
#
#  dt = 75 , Output #162
#  dt = 75 , Output #163
#  Big Dist Output #164
#
#  dt = 75 , Output #164
#  Restart Output #165
#
#  dt = 75 , Output #165
#  Big Dist Output #166
#
#  Dist Output #166
#
#  dt = 75 , Output #166
#  dt = 75 , Output #167
#  Big Dist Output #168
#
#  dt = 75 , Output #168
#  dt = 75 , Output #169
#  Big Dist Output #170
#
#  Dist Output #170
#
#  dt = 75 , Output #170
#  dt = 75 , Output #171
#  Big Dist Output #172
#
#  dt = 75 , Output #172
#  dt = 75 , Output #173
#  Big Dist Output #174
#
#  Dist Output #174
#
#  dt = 75 , Output #174
#  dt = 75 , Output #175
#  Big Dist Output #176
#
#  dt = 75 , Output #176
#  dt = 75 , Output #177
#  Big Dist Output #178
#
#  Dist Output #178
#
#  dt = 75 , Output #178
#  dt = 75 , Output #179
#  Big Dist Output #180
#
#  dt = 75 , Output #180
#  dt = 75 , Output #181
#  Big Dist Output #182
#
#  Dist Output #182
#
#  dt = 75 , Output #182
#  Restart Output #183
#
#  dt = 75 , Output #183
#  Big Dist Output #184
#
#  dt = 75 , Output #184
#  Big Dist Output #185
#
#  dt = 75 , Output #185
#  Dist Output #186
#
#  dt = 75 , Output #186
#  Big Dist Output #187
#
#  dt = 75 , Output #187
#  dt = 75 , Output #188
#  Big Dist Output #189
#
#  dt = 75 , Output #189
#  Dist Output #190
#
#  dt = 75 , Output #190
#  Big Dist Output #191
#
#  dt = 75 , Output #191
#  dt = 75 , Output #192
#  Dist Output #193
#
#  Big Dist Output #193
#
#  dt = 75 , Output #193
#  dt = 75 , Output #194
#  Big Dist Output #195
#
#  dt = 75 , Output #195
#  dt = 75 , Output #196
#  Dist Output #197
#
#  Big Dist Output #197
#
#  dt = 75 , Output #197
#  dt = 75 , Output #198
#  Big Dist Output #199
#
#  dt = 75 , Output #199
#  dt = 75 , Output #200Simulation took 267 second(s).
# 	Unloading the conflicting module 'intel/13.cs'
#
#
# The 'gcc/4.9.3' module is being loaded
#
# 	These modules were already loaded: ATS intel/17.0.1 idl/8.1 soxr/0.1.0 ffmpeg/1.1.1
#
# 	Unloading the conflicting module 'hdf5/1.8.18-shared'
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...
# Initializing parallel environment ...
# Initializing parallel environment ...     done
#
#      done
#
#      done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing parallel environment ...     done
#
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 60
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 2503.89 eV
# Corresponding thermal velocity        = 2.09855e+07 m/s
#
# Corresponding e-i log Lambda          = 6.46692
# Corresponding e-i collision frequency = 9.0027e+12 Hz
# Corresponding tau_e-i / tau_p         = 198.11
# Corresponding e-i mean free path      = 2.33102 microns
#
# Corresponding e-e log Lambda          = 7.64846
# Corresponding e-e collision frequency = 1.77456e+11 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 75 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#  dt = 50 , Output #1
#  Big Dist Output #2
#
#  dt = 50 , Output #2
#  dt = 50 , Output #3
#  Dist Output #4
#
#  Big Dist Output #4
#
#  dt = 50 , Output #4
#  dt = 50 , Output #5
#  Big Dist Output #6
#
#  dt = 50 , Output #6
#  dt = 50 , Output #7
#  Dist Output #8
#
#  Big Dist Output #8
#
#  dt = 50 , Output #8
#  dt = 50 , Output #9
#  Big Dist Output #10
#
#  dt = 50 , Output #10
#  dt = 50 , Output #11
#  Dist Output #12
#
#  Big Dist Output #12
#
#  dt = 50 , Output #12
#  dt = 50 , Output #13
#  Big Dist Output #14
#
#  dt = 50 , Output #14
#  dt = 50 , Output #15
#  Dist Output #16
#
#  Big Dist Output #16
#
#  dt = 50 , Output #16
#  dt = 50 , Output #17
#  Big Dist Output #18
#
#  dt = 50 , Output #18
#  Restart Output #19
#
#  dt = 50 , Output #19
#  Dist Output #20
#
#  Big Dist Output #20
#
#  dt = 50 , Output #20
#  dt = 50 , Output #21
#  Big Dist Output #22
#
#  dt = 50 , Output #22
#  dt = 50 , Output #23
#  Dist Output #24
#
#  Big Dist Output #24
#
#  dt = 50 , Output #24
#  dt = 50 , Output #25
#  Big Dist Output #26
#
#  dt = 50 , Output #26
#  dt = 50 , Output #27
#  Dist Output #28
#
#  Big Dist Output #28
#
#  dt = 50 , Output #28
#  dt = 50 , Output #29
#  Big Dist Output #30
#
#  dt = 50 , Output #30
#  dt = 50 , Output #31
#  Dist Output #32
#
#  Big Dist Output #32
#
#  dt = 50 , Output #32
#  dt = 50 , Output #33
#  Big Dist Output #34
#
#  dt = 50 , Output #34
#  dt = 50 , Output #35
#  Dist Output #36
#
#  Big Dist Output #36
#
#  dt = 50 , Output #36
#  Restart Output #37
#
#  dt = 50 , Output #37
#  Big Dist Output #38
#
#  dt = 50 , Output #38
#  dt = 50 , Output #39
#  Dist Output #40
#
#  Big Dist Output #40
#
#  dt = 50 , Output #40
#  dt = 50 , Output #41
#  Big Dist Output #42
#
#  dt = 50 , Output #42
#  dt = 50 , Output #43
#  Dist Output #44
#
#  Big Dist Output #44
#
#  dt = 50 , Output #44
#  dt = 50 , Output #45
#  Big Dist Output #46
#
#  dt = 50 , Output #46
#  dt = 50 , Output #47
#  Dist Output #48
#
#  Big Dist Output #48
#
#  dt = 50 , Output #48
#  dt = 50 , Output #49
#  Big Dist Output #50
#
#  dt = 50 , Output #50
#  dt = 50 , Output #51
#  Dist Output #52
#
#  Big Dist Output #52
#
#  dt = 50 , Output #52
#  dt = 50 , Output #53
#  Big Dist Output #54
#
#  dt = 50 , Output #54
#  Restart Output #55
#
#  dt = 50 , Output #55
#  Dist Output #56
#
#  Big Dist Output #56
#
#  dt = 50 , Output #56
#  dt = 50 , Output #57
#  Big Dist Output #58
#
#  dt = 50 , Output #58
#  Dist Output #59
#
#  dt = 50 , Output #59
#  Big Dist Output #60
#
#  dt = 50 , Output #60
#  dt = 50 , Output #61
#  Big Dist Output #62
#
#  dt = 50 , Output #62
#  Dist Output #63
#
#  dt = 50 , Output #63
#  Big Dist Output #64
#
#  dt = 50 , Output #64
#  dt = 50 , Output #65
#  Big Dist Output #66
#
#  dt = 50 , Output #66
#  Dist Output #67
#
#  dt = 50 , Output #67
#  Big Dist Output #68
#
#  dt = 50 , Output #68
#  dt = 50 , Output #69
#  Big Dist Output #70
#
#  dt = 50 , Output #70
#  Dist Output #71
#
#  dt = 50 , Output #71
#  Big Dist Output #72
#
#  dt = 50 , Output #72
#  dt = 50 , Output #73
#  Restart Output #74
#
#  Big Dist Output #74
#
#  dt = 50 , Output #74
#  Dist Output #75
#
#  dt = 50 , Output #75
#  Big Dist Output #76
#
#  dt = 50 , Output #76
#  dt = 50 , Output #77
#  Big Dist Output #78
#
#  dt = 50 , Output #78
#  Dist Output #79
#
#  dt = 50 , Output #79
#  Big Dist Output #80
#
#  dt = 50 , Output #80
#  dt = 50 , Output #81
#  Big Dist Output #82
#
#  dt = 50 , Output #82
#  Dist Output #83
#
#  dt = 50 , Output #83
#  Big Dist Output #84
#
#  dt = 50 , Output #84
#  dt = 50 , Output #85
#  Big Dist Output #86
#
#  dt = 50 , Output #86
#  Dist Output #87
#
#  dt = 50 , Output #87
#  Big Dist Output #88
#
#  dt = 50 , Output #88
#  dt = 50 , Output #89
#  Big Dist Output #90
#
#  dt = 50 , Output #90
#  Dist Output #91
#
#  dt = 50 , Output #91
#  Restart Output #92
#
#  Big Dist Output #92
#
#  dt = 50 , Output #92
#  dt = 50 , Output #93
#  Big Dist Output #94
#
#  dt = 50 , Output #94
#  Dist Output #95
#
#  dt = 50 , Output #95
#  Big Dist Output #96
#
#  dt = 50 , Output #96
#  dt = 50 , Output #97
#  Big Dist Output #98
#
#  dt = 50 , Output #98
#  Dist Output #99
#
#  dt = 50 , Output #99
#  Big Dist Output #100
#
#  dt = 50 , Output #100
#  dt = 50 , Output #101
#  Big Dist Output #102
#
#  dt = 50 , Output #102
#  Dist Output #103
#
#  dt = 50 , Output #103
#  Big Dist Output #104
#
#  dt = 50 , Output #104
#  dt = 50 , Output #105
#  Big Dist Output #106
#
#  dt = 50 , Output #106
#  Dist Output #107
#
#  dt = 50 , Output #107
#  Big Dist Output #108
#
#  dt = 50 , Output #108
#  dt = 50 , Output #109
#  Big Dist Output #110
#
#  Restart Output #110
#
#  dt = 50 , Output #110
#  Dist Output #111
#
#  dt = 50 , Output #111
#  Big Dist Output #112
#
#  dt = 50 , Output #112
#  dt = 50 , Output #113
#  Big Dist Output #114
#
#  dt = 50 , Output #114
#  Dist Output #115
#
#  dt = 50 , Output #115
#  Big Dist Output #116
#
#  dt = 50 , Output #116
#  dt = 50 , Output #117
#  Big Dist Output #118
#
#  dt = 50 , Output #118
#  Dist Output #119
#
#  dt = 50 , Output #119
#  Big Dist Output #120
#
#  dt = 50 , Output #120
#  dt = 50 , Output #121
#  Big Dist Output #122
#
#  dt = 50 , Output #122
#  Dist Output #123
#
#  dt = 50 , Output #123
#  Big Dist Output #124
#
#  dt = 50 , Output #124
#  dt = 50 , Output #125
#  Big Dist Output #126
#
#  Dist Output #126
#
#  dt = 50 , Output #126
#  dt = 50 , Output #127
#  Big Dist Output #128
#
#  Restart Output #128
#
#  dt = 50 , Output #128
#  dt = 50 , Output #129
#  Big Dist Output #130
#
#  Dist Output #130
#
#  dt = 50 , Output #130
#  dt = 50 , Output #131
#  Big Dist Output #132
#
#  dt = 50 , Output #132
#  dt = 50 , Output #133
#  Big Dist Output #134
#
#  Dist Output #134
#
#  dt = 50 , Output #134
#  dt = 50 , Output #135
#  Big Dist Output #136
#
#  dt = 50 , Output #136
#  dt = 50 , Output #137
#  Big Dist Output #138
#
#  Dist Output #138
#
#  dt = 50 , Output #138
#  dt = 50 , Output #139
#  Big Dist Output #140
#
#  dt = 50 , Output #140
#  dt = 50 , Output #141
#  Big Dist Output #142
#
#  Dist Output #142
#
#  dt = 50 , Output #142
#  dt = 50 , Output #143
#  Big Dist Output #144
#
#  dt = 50 , Output #144
#  dt = 50 , Output #145
#  Big Dist Output #146
#
#  Dist Output #146
#
#  dt = 50 , Output #146
#  Restart Output #147
#
#  dt = 50 , Output #147
#  Big Dist Output #148
#
#  dt = 50 , Output #148
#  dt = 50 , Output #149
#  Big Dist Output #150
#
#  Dist Output #150
#
#  dt = 50 , Output #150
#  dt = 50 , Output #151
#  Big Dist Output #152
#
#  dt = 50 , Output #152
#  dt = 50 , Output #153
#  Big Dist Output #154
#
#  Dist Output #154
#
#  dt = 50 , Output #154
#  dt = 50 , Output #155
#  Big Dist Output #156
#
#  dt = 50 , Output #156
#  dt = 50 , Output #157
#  Big Dist Output #158
#
#  Dist Output #158
#
#  dt = 50 , Output #158
#  dt = 50 , Output #159
#  Big Dist Output #160
#
#  dt = 50 , Output #160
#  dt = 50 , Output #161
#  Big Dist Output #162
#
#  Dist Output #162
#
#  dt = 50 , Output #162
#  dt = 50 , Output #163
#  Big Dist Output #164
#
#  dt = 50 , Output #164
#  Restart Output #165
#
#  dt = 50 , Output #165
#  Big Dist Output #166
#
#  Dist Output #166
#
#  dt = 50 , Output #166
#  dt = 50 , Output #167
#  Big Dist Output #168
#
#  dt = 50 , Output #168
#  dt = 50 , Output #169
#  Big Dist Output #170
#
#  Dist Output #170
#
#  dt = 50 , Output #170
#  dt = 50 , Output #171
#  Big Dist Output #172
#
#  dt = 50 , Output #172
#  dt = 50 , Output #173
#  Big Dist Output #174
#
#  Dist Output #174
#
#  dt = 50 , Output #174
#  dt = 50 , Output #175
#  Big Dist Output #176
#
#  dt = 50 , Output #176
#  dt = 50 , Output #177
#  Big Dist Output #178
#
#  Dist Output #178
#
#  dt = 50 , Output #178
#  dt = 50 , Output #179
#  Big Dist Output #180
#
#  dt = 50 , Output #180
#  dt = 50 , Output #181
#  Big Dist Output #182
#
#  Dist Output #182
#
#  dt = 50 , Output #182
#  Restart Output #183
#
#  dt = 50 , Output #183
#  Big Dist Output #184
#
#  dt = 50 , Output #184
#  Big Dist Output #185
#
#  dt = 50 , Output #185
#  Dist Output #186
#
#  dt = 50 , Output #186
#  Big Dist Output #187
#
#  dt = 50 , Output #187
#  dt = 50 , Output #188
#  Big Dist Output #189
#
#  dt = 50 , Output #189
#  Dist Output #190
#
#  dt = 50 , Output #190
#  Big Dist Output #191
#
#  dt = 50 , Output #191
#  dt = 50 , Output #192
#  Dist Output #193
#
#  Big Dist Output #193
#
#  dt = 50 , Output #193
#  dt = 50 , Output #194
#  Big Dist Output #195
#
#  dt = 50 , Output #195
#  dt = 50 , Output #196
#  Dist Output #197
#
#  Big Dist Output #197
#
#  dt = 50 , Output #197
#  dt = 50 , Output #198
#  Big Dist Output #199
#
#  dt = 50 , Output #199
#  dt = 50 , Output #200Simulation took 83 second(s).

# %%
# !mkdir z60bz001 && cp inputdeck.z60bz001 ./z60bz001/inputdeck && cd z60bz001 && ln -s ../oshun.e . && ./oshun.e inputdeck
# !mkdir z60bz0001 && cp inputdeck.z60bz0001 ./z60bz0001/inputdeck && cd z60bz0001 && ln -s ../oshun.e . && ./oshun.e inputdeck
# !mkdir z60bz01 && cp inputdeck.z60bz01 ./z60bz01/inputdeck && cd z60bz01 && ln -s ../oshun.e . && ./oshun.e inputdeck
# Out:
# Initializing parallel environment ...     done
#
#
# Initializing grid ...     done
# Initializing restart environment ...     done
# Initializing state variable ...     done
# Initializing plasma profile ...     done
# Initializing collision module ...     done
# Initializing hydro module ...     done
# Initializing particle tracker ...     done
# Initializing output module ...     done
# Output #0 ...     done
# Distribution function output #0 ...     done
#
#
# ------- ---------------- */*/*/*/*/* ---------------- -------
# ------- ,-----.  ,---.  ,--.  ,--.,--. ,--.,--.  ,--. -------
# -------'  .-.  ''   .-' |  '--'  ||  | |  ||  ,'.|  | -------
# -------|  | |  |`.  `-. |  .--.  ||  | |  ||  |' '  | -------
# -------'  '-'  '.-'    ||  |  |  |'  '-'  '|  | `   | -------
# ------- `-----' `-----' `--'  `--' `-----' `--'  `--' -------
# ------- ---------------- */*/*/*/*/* ---------------- -------
#
#
# --------------- OSHUN Beta - 1/2D+3P ---------------
#     Particle-in-Cell and Kinetic Simulation Center
# ------------------- UCLA - 2017 --------------------
# ----------------- Reference Units ------------------
# normalizing density                   = 1e+21 / cc
# plasma frequency                      = 1.78352e+15 Hz
# background ions - Z                   = 60
# normalizing magnetic field            = 10140.5 T
# Reference Temperature                 = 2503.89 eV
# Corresponding thermal velocity        = 2.09855e+07 m/s
#
# Corresponding e-i log Lambda          = 6.46692
# Corresponding e-i collision frequency = 9.0027e+12 Hz
# Corresponding tau_e-i / tau_p         = 198.11
# Corresponding e-i mean free path      = 2.33102 microns
#
# Corresponding e-e log Lambda          = 7.64846
# Corresponding e-e collision frequency = 1.77456e+11 Hz
#
#
# --------------  Simulation parameters --------------
# skin depth (normalizing distance)     = 0.16809 microns
# plasma period (normalizing time)      = 0.560688 fs
# Time step     (normalizing time)      = 75 plasma periods
#
#
# Starting Semi-Implicit, 1D OSHUN
#
#  dt = 50 , Output #1
#  Big Dist Output #2
#
#  dt = 50 , Output #2
#  dt = 50 , Output #3
#  Dist Output #4
#
#  Big Dist Output #4
#
#  dt = 50 , Output #4
#  dt = 50 , Output #5
#  Big Dist Output #6
#
#  dt = 50 , Output #6
#  dt = 50 , Output #7
#  Dist Output #8
#
#  Big Dist Output #8
#
#  dt = 50 , Output #8
#  dt = 50 , Output #9
#  Big Dist Output #10
#
#  dt = 50 , Output #10
#  dt = 50 , Output #11
#  Dist Output #12
#
#  Big Dist Output #12
#
#  dt = 50 , Output #12
#  dt = 50 , Output #13
#  Big Dist Output #14
#
#  dt = 50 , Output #14
#  dt = 50 , Output #15
#  Dist Output #16
#
#  Big Dist Output #16
#
#  dt = 50 , Output #16
#  dt = 50 , Output #17
#  Big Dist Output #18
#
#  dt = 50 , Output #18
#  Restart Output #19
#
#  dt = 50 , Output #19
#  Dist Output #20
#
#  Big Dist Output #20
#
#  dt = 50 , Output #20
#  dt = 50 , Output #21
#  Big Dist Output #22
#
#  dt = 50 , Output #22
#  dt = 50 , Output #23
#  Dist Output #24
#
#  Big Dist Output #24
#
#  dt = 50 , Output #24
#  dt = 50 , Output #25
#  Big Dist Output #26
#
#  dt = 50 , Output #26
#  dt = 50 , Output #27
#  Dist Output #28
#
#  Big Dist Output #28
#
#  dt = 50 , Output #28
#  dt = 50 , Output #29
#  Big Dist Output #30
#
#  dt = 50 , Output #30
#  dt = 50 , Output #31
#  Dist Output #32
#
#  Big Dist Output #32
#
#  dt = 50 , Output #32
#  dt = 50 , Output #33
#  Big Dist Output #34
#
#  dt = 50 , Output #34
#  dt = 50 , Output #35
#  Dist Output #36
#
#  Big Dist Output #36
#
#  dt = 50 , Output #36
#  Restart Output #37
#
#  dt = 50 , Output #37
#  Big Dist Output #38
#
#  dt = 50 , Output #38
#  dt = 50 , Output #39
#  Dist Output #40
#
#  Big Dist Output #40
#
#  dt = 50 , Output #40
#  dt = 50 , Output #41
#  Big Dist Output #42
#
#  dt = 50 , Output #42
#  dt = 50 , Output #43
#  Dist Output #44
#
#  Big Dist Output #44
#
#  dt = 50 , Output #44
#  dt = 50 , Output #45
#  Big Dist Output #46
#
#  dt = 50 , Output #46
#  dt = 50 , Output #47
#  Dist Output #48
#
#  Big Dist Output #48
#
#  dt = 50 , Output #48
#  dt = 50 , Output #49
#  Big Dist Output #50
#
#  dt = 50 , Output #50
#  dt = 50 , Output #51
#  Dist Output #52
#
#  Big Dist Output #52
#
#  dt = 50 , Output #52
#  dt = 50 , Output #53
#  Big Dist Output #54
#
#  dt = 50 , Output #54
#  Restart Output #55
#
#  dt = 50 , Output #55
#  Dist Output #56
#
#  Big Dist Output #56
#
#  dt = 50 , Output #56
#  dt = 50 , Output #57
#  Big Dist Output #58
#
#  dt = 50 , Output #58
#  Dist Output #59
#
#  dt = 50 , Output #59
#  Big Dist Output #60
#
#  dt = 50 , Output #60
#  dt = 50 , Output #61
#  Big Dist Output #62
#
#  dt = 50 , Output #62
#  Dist Output #63
#
#  dt = 50 , Output #63
#  Big Dist Output #64
#
#  dt = 50 , Output #64
#  dt = 50 , Output #65
#  Big Dist Output #66
#
#  dt = 50 , Output #66
#  Dist Output #67
#
#  dt = 50 , Output #67
#  Big Dist Output #68
#
#  dt = 50 , Output #68
#  dt = 50 , Output #69
#  Big Dist Output #70
#
#  dt = 50 , Output #70
#  Dist Output #71
#
#  dt = 50 , Output #71
#  Big Dist Output #72
#
#  dt = 50 , Output #72
#  dt = 50 , Output #73
#  Restart Output #74
#
#  Big Dist Output #74
#
#  dt = 50 , Output #74
#  Dist Output #75
#
#  dt = 50 , Output #75
#  Big Dist Output #76
#
#  dt = 50 , Output #76
#  dt = 50 , Output #77
#  Big Dist Output #78
#
#  dt = 50 , Output #78
#  Dist Output #79
#
#  dt = 50 , Output #79
#  Big Dist Output #80
#
#  dt = 50 , Output #80
#  dt = 50 , Output #81
#  Big Dist Output #82
#
#  dt = 50 , Output #82
#  Dist Output #83
#
#  dt = 50 , Output #83
#  Big Dist Output #84
#
#  dt = 50 , Output #84
#  dt = 50 , Output #85
#  Big Dist Output #86
#
#  dt = 50 , Output #86
#  Dist Output #87
#
#  dt = 50 , Output #87
#  Big Dist Output #88
#
#  dt = 50 , Output #88
#  dt = 50 , Output #89
#  Big Dist Output #90
#
#  dt = 50 , Output #90
#  Dist Output #91
#
#  dt = 50 , Output #91
#  Restart Output #92
#
#  Big Dist Output #92
#
#  dt = 50 , Output #92
#  dt = 50 , Output #93
#  Big Dist Output #94
#
#  dt = 50 , Output #94
#  Dist Output #95
#
#  dt = 50 , Output #95
#  Big Dist Output #96
#
#  dt = 50 , Output #96
#  dt = 50 , Output #97
#  Big Dist Output #98
#
#  dt = 50 , Output #98
#  Dist Output #99
#
#  dt = 50 , Output #99
#  Big Dist Output #100
#
#  dt = 50 , Output #100
#  dt = 50 , Output #101
#  Big Dist Output #102
#
#  dt = 50 , Output #102
#  Dist Output #103
#
#  dt = 50 , Output #103
#  Big Dist Output #104
#
#  dt = 50 , Output #104
#  dt = 50 , Output #105
#  Big Dist Output #106
#
#  dt = 50 , Output #106
#  Dist Output #107
#
#  dt = 50 , Output #107
#  Big Dist Output #108
#
#  dt = 50 , Output #108
#  dt = 50 , Output #109
#  Big Dist Output #110
#
#  Restart Output #110
#
#  dt = 50 , Output #110
#  Dist Output #111
#
#  dt = 50 , Output #111
#  Big Dist Output #112
#
#  dt = 50 , Output #112
#  dt = 50 , Output #113
#  Big Dist Output #114
#
#  dt = 50 , Output #114
#  Dist Output #115
#
#  dt = 50 , Output #115
#  Big Dist Output #116
#
#  dt = 50 , Output #116
#  dt = 50 , Output #117
#  Big Dist Output #118
#
#  dt = 50 , Output #118
#  Dist Output #119
#
#  dt = 50 , Output #119
#  Big Dist Output #120
#
#  dt = 50 , Output #120
#  dt = 50 , Output #121
#  Big Dist Output #122
#
#  dt = 50 , Output #122
#  Dist Output #123
#
#  dt = 50 , Output #123
#  Big Dist Output #124
#
#  dt = 50 , Output #124
#  dt = 50 , Output #125
#  Big Dist Output #126
#
#  Dist Output #126
#
#  dt = 50 , Output #126
#  dt = 50 , Output #127
#  Big Dist Output #128
#
#  Restart Output #128
#
#  dt = 50 , Output #128
#  dt = 50 , Output #129
#  Big Dist Output #130
#
#  Dist Output #130
#
#  dt = 50 , Output #130
#  dt = 50 , Output #131
#  Big Dist Output #132
#
#  dt = 50 , Output #132
#  dt = 50 , Output #133
#  Big Dist Output #134
#
#  Dist Output #134
#
#  dt = 50 , Output #134
#  dt = 50 , Output #135
#  Big Dist Output #136
#
#  dt = 50 , Output #136
#  dt = 50 , Output #137
#  Big Dist Output #138
#
#  Dist Output #138
#
#  dt = 50 , Output #138
#  dt = 50 , Output #139
#  Big Dist Output #140
#
#  dt = 50 , Output #140
#  dt = 50 , Output #141
#  Big Dist Output #142
#
#  Dist Output #142
#
#  dt = 50 , Output #142
#  dt = 50 , Output #143
#  Big Dist Output #144
#
#  dt = 50 , Output #144
#  dt = 50 , Output #145
#  Big Dist Output #146
#
#  Dist Output #146
#
#  dt = 50 , Output #146
#  Restart Output #147
#
#  dt = 50 , Output #147
#  Big Dist Output #148
#
#  dt = 50 , Output #148
#  dt = 50 , Output #149
#  Big Dist Output #150
#
#  Dist Output #150
#
#  dt = 50 , Output #150
#  dt = 50 , Output #151
#  Big Dist Output #152
#
#  dt = 50 , Output #152
#  dt = 50 , Output #153
#  Big Dist Output #154
#
#  Dist Output #154
#
#  dt = 50 , Output #154
#  dt = 50 , Output #155
#  Big Dist Output #156
#  dt = 50 , Output #156
#  dt = 50 , Output #157
#  Big Dist Output #158
#
#  Dist Output #158
#
#  dt = 50 , Output #158
#  dt = 50 , Output #159
#  Big Dist Output #160
#
#  dt = 50 , Output #160
#  dt = 50 , Output #161
#  Big Dist Output #162
#
#  Dist Output #162
#
#  dt = 50 , Output #162
#  dt = 50 , Output #163
#  Big Dist Output #164
#
#  dt = 50 , Output #164
#  Restart Output #165
#
#  dt = 50 , Output #165
#  Big Dist Output #166
#
#  Dist Output #166
#
#  dt = 50 , Output #166
#  dt = 50 , Output #167
#  Big Dist Output #168
#
#  dt = 50 , Output #168
#  dt = 50 , Output #169
#  Big Dist Output #170
#
#  Dist Output #170
#
#  dt = 50 , Output #170
#  dt = 50 , Output #171
#  Big Dist Output #172
#
#  dt = 50 , Output #172
#  dt = 50 , Output #173
#  Big Dist Output #174
#
#  Dist Output #174
#
#  dt = 50 , Output #174
#  dt = 50 , Output #175
#  Big Dist Output #176
#
#  dt = 50 , Output #176
#  dt = 50 , Output #177
#  Big Dist Output #178
#
#  Dist Output #178
#
#  dt = 50 , Output #178
#  dt = 50 , Output #179
#  Big Dist Output #180
#
#  dt = 50 , Output #180
#  dt = 50 , Output #181
#  Big Dist Output #182
#
#  Dist Output #182
#
#  dt = 50 , Output #182
#  Restart Output #183
#
#  dt = 50 , Output #183
#  Big Dist Output #184
#
#  dt = 50 , Output #184
#  Big Dist Output #185
#
#  dt = 50 , Output #185
#  Dist Output #186
#
#  dt = 50 , Output #186
#  Big Dist Output #187
#
#  dt = 50 , Output #187
#  dt = 50 , Output #188
#  Big Dist Output #189
#
#  dt = 50 , Output #189
#  Dist Output #190
#
#  dt = 50 , Output #190
#  Big Dist Output #191
#
#  dt = 50 , Output #191
#  dt = 50 , Output #192
#  Dist Output #193
#
#  Big Dist Output #193
#
#  dt = 50 , Output #193
#  dt = 50 , Output #194
#  Big Dist Output #195
#
#  dt = 50 , Output #195
#  dt = 50 , Output #196
#  Dist Output #197
#
#  Big Dist Output #197
#
#  dt = 50 , Output #197
#  dt = 50 , Output #198
#  Big Dist Output #199
#
#  dt = 50 , Output #199
#  dt = 50 , Output #200Simulation took 1071 second(s).

# %%
plot_kappa(60, './zarchisv3')
timez2, colltimez2, kappaz2, kappaEHz2 = get_kappa_sim_theo('./zarchisv3', start_steps=199)
print(timez2,colltimez2,kappaz2,kappaEHz2)
print('theory'+str(heatflow.getKappaEH([0.173],[60])))
# Out:
# [ 9900.5] [ 573.07504953] [ 4.39638633] [ 4.42144731]
# theory(array([ 12.67]), array([ 4.39169164]), array([ 4.64626171]))

# %%
plot_kappa(60, './z60bz001')
timez2, colltimez2, kappaz2, kappaEHz2 = get_kappa_sim_theo('./z60bz001', start_steps=1)
print(timez2,colltimez2,kappaz2,kappaEHz2)
print('theory '+str(heatflow.getKappaEH([0.198],[60])[0][0]))
print('theory '+str(heatflow.getKappaEH([0.198],[60])[1][0]))
print(abs(kappaEHz2-heatflow.getKappaEH([0.198],[60])[1][0])/heatflow.getKappaEH([0.198],[60])[1][0])
# Out:
# [   300.    600.    900.   1200.   1500.   1800.   2100.   2400.   2700.
#    3000.   3300.   3600.   3900.   4200.   4500.   4800.   5100.   5400.
#    5700.   6000.   6300.   6600.   6900.   7200.   7500.   7800.   8100.
#    8400.   8700.   9000.   9300.   9600.   9900.  10150.  10450.  10750.
#   11050.  11350.  11650.  11950.  12250.  12550.  12850.  13150.  13450.
#   13750.  14050.  14350.  14650.  14950.  15250.  15550.  15850.  16150.
#   16450.  16750.  17050.  17350.  17650.  17950.  18250.  18550.  18850.
#   19150.  19450.  19750.  20050.  20300.  20600.  20900.  21200.  21500.
#   21800.  22100.  22400.  22700.  23000.  23300.  23600.  23900.  24200.
#   24500.  24800.  25100.  25400.  25700.  26000.  26300.  26600.  26900.
#   27200.  27500.  27800.  28100.  28400.  28700.  29000.  29300.  29600.
#   29900.  30150.  30450.  30750.  31050.  31350.  31650.  31950.  32250.
#   32550.  32850.  33150.  33450.  33750.  34050.  34350.  34650.  34950.
#   35250.  35550.  35850.  36150.  36450.  36750.  37050.  37350.  37650.
#   37950.  38250.  38550.  38850.  39150.  39450.  39750.  40050.  40300.
#   40600.  40900.  41200.  41500.  41800.  42100.  42400.  42700.  43000.
#   43300.  43600.  43900.  44200.  44500.  44800.  45100.  45400.  45700.
#   46000.  46300.  46600.  46900.  47200.  47500.  47800.  48100.  48400.
#   48700.  49000.  49300.  49600.  49900.  50150.  50450.  50750.  51050.
#   51350.  51650.  51950.  52250.  52550.  52850.  53150.  53450.  53750.
#   54050.  54350.  54650.  54950.  55250.  55550.  55850.  56150.  56450.
#   56750.  57050.  57350.  57650.  57950.  58250.  58550.  58850.  59150.
#   59450.] [   1.51426874    3.02853749    4.54280623    6.05707498    7.57134372
#     9.08561246   10.59988121   12.11414995   13.6284187    15.14268744
#    16.65695619   18.17122493   19.68549367   21.19976242   22.71403116
#    24.22829991   25.74256865   27.25683739   28.77110614   30.28537488
#    31.79964363   33.31391237   34.82818112   36.34244986   37.8567186
#    39.37098735   40.88525609   42.39952484   43.91379358   45.42806232
#    46.94233107   48.45659981   49.97086856   51.23275918   52.74702792
#    54.26129667   55.77556541   57.28983415   58.8041029    60.31837164
#    61.83264039   63.34690913   64.86117787   66.37544662   67.88971536
#    69.40398411   70.91825285   72.4325216    73.94679034   75.46105908
#    76.97532783   78.48959657   80.00386532   81.51813406   83.0324028
#    84.54667155   86.06094029   87.57520904   89.08947778   90.60374653
#    92.11801527   93.63228401   95.14655276   96.6608215    98.17509025
#    99.68935899  101.20362773  102.46551835  103.9797871   105.49405584
#   107.00832459  108.52259333  110.03686208  111.55113082  113.06539956
#   114.57966831  116.09393705  117.6082058   119.12247454  120.63674328
#   122.15101203  123.66528077  125.17954952  126.69381826  128.20808701
#   129.72235575  131.23662449  132.75089324  134.26516198  135.77943073
#   137.29369947  138.80796821  140.32223696  141.8365057   143.35077445
#   144.86504319  146.37931194  147.89358068  149.40784942  150.92211817
#   152.18400879  153.69827753  155.21254628  156.72681502  158.24108376
#   159.75535251  161.26962125  162.78389     164.29815874  165.81242749
#   167.32669623  168.84096497  170.35523372  171.86950246  173.38377121
#   174.89803995  176.41230869  177.92657744  179.44084618  180.95511493
#   182.46938367  183.98365242  185.49792116  187.0121899   188.52645865
#   190.04072739  191.55499614  193.06926488  194.58353362  196.09780237
#   197.61207111  199.12633986  200.6406086   202.15487735  203.41676797
#   204.93103671  206.44530545  207.9595742   209.47384294  210.98811169
#   212.50238043  214.01664917  215.53091792  217.04518666  218.55945541
#   220.07372415  221.5879929   223.10226164  224.61653038  226.13079913
#   227.64506787  229.15933662  230.67360536  232.1878741   233.70214285
#   235.21641159  236.73068034  238.24494908  239.75921783  241.27348657
#   242.78775531  244.30202406  245.8162928   247.33056155  248.84483029
#   250.35909903  251.87336778  253.1352584   254.64952714  256.16379589
#   257.67806463  259.19233338  260.70660212  262.22087086  263.73513961
#   265.24940835  266.7636771   268.27794584  269.79221458  271.30648333
#   272.82075207  274.33502082  275.84928956  277.3635583   278.87782705
#   280.39209579  281.90636454  283.42063328  284.93490203  286.44917077
#   287.96343951  289.47770826  290.991977    292.50624575  294.02051449
#   295.53478323  297.04905198  298.56332072  300.07758947] [ 2.82459462  4.21084634  5.03825194  5.46384454  5.59531904  5.51756327
#   5.30140305  5.00551095  4.68001864  4.36038501  4.07399333  3.83845959
#   3.66274147  3.55030112  3.49711929  3.49515913  3.53418268  3.60215358
#   3.68786868  3.78102677  3.87085     3.95052289  4.01398164  4.0603835
#   4.08730879  4.09564551  4.08800337  4.06768863  4.03864461  4.00472435
#   3.96934365  3.93607726  3.90780467  3.88935986  3.87382215  3.86596877
#   3.86518726  3.87049018  3.88050978  3.89378251  3.90867151  3.92357325
#   3.9369126   3.94800882  3.95629859  3.9613491   3.96313356  3.96183069
#   3.95812287  3.9524079   3.94556091  3.93834794  3.93141042  3.92529648
#   3.92050525  3.9172288   3.9155333   3.91541224  3.91660846  3.91899045
#   3.92207878  3.92556008  3.92902482  3.93229202  3.93498956  3.93697713
#   3.93815168  3.93855275  3.93830124  3.93726549  3.9358249   3.93400095
#   3.93212432  3.93015162  3.92842975  3.92705638  3.92609139  3.9255313
#   3.92544449  3.92571046  3.92623051  3.92713321  3.92805877  3.92904225
#   3.92999505  3.93075387  3.93130598  3.93162031  3.93167658  3.93163931
#   3.93128334  3.93075581  3.93017546  3.92958785  3.92895071  3.92831403
#   3.92795054  3.92758401  3.92739104  3.92735674  3.92739446  3.9275202
#   3.92776065  3.92803874  3.92840315  3.92859834  3.92889865  3.92904564
#   3.92918462  3.92921409  3.92913718  3.9289852   3.92880339  3.92860239
#   3.9283162   3.9280671   3.92786709  3.92765956  3.92755863  3.92743425
#   3.92738784  3.9273166   3.92741429  3.92744729  3.92746011  3.92754951
#   3.92761527  3.92771367  3.927699    3.92769656  3.92765072  3.92759088
#   3.92752028  3.92737831  3.92729318  3.92711706  3.92707428  3.92688356
#   3.92676612  3.92671248  3.92657948  3.92664384  3.92659649  3.92660231
#   3.9265704   3.92654818  3.92590153  3.92626691  3.92635602  3.92647127
#   3.92638574  3.92505071  3.92595775  3.92612615  3.92616808  3.92618067
#   3.92611634  3.92604254  3.92604731  3.92592711  3.92586994  3.92582418
#   3.92582476  3.92575518  3.92564321  3.92566942  3.92560164  3.92563487
#   3.92550853  3.92543582  3.92543229  3.92541402  3.92530469  3.92526057
#   3.92529334  3.92522693  3.92512257  3.92505975  3.92503324  3.92494961
#   3.9248883   3.92482374  3.92479988  3.92477056  3.92477503  3.92475355
#   3.92462714  3.92467608  3.92457257  3.92462243  3.92452169  3.92451491
#   3.92453038  3.92438452  3.92441656  3.92435329  3.92427068  3.92425611
#   3.92420647] [ 3.98402825  3.98398211  3.98393563  3.98388889  3.98384196  3.98379487
#   3.98374767  3.98370036  3.98365298  3.98360552  3.98355802  3.98351046
#   3.98346285  3.98341521  3.98336753  3.98331981  3.98327206  3.98322428
#   3.98317647  3.98312864  3.98308078  3.9830329   3.982985    3.98293709
#   3.98288915  3.98284121  3.98279325  3.98274528  3.9826973   3.98264931
#   3.98260132  3.98255332  3.98250531  3.9824653   3.98241729  3.98236926
#   3.98232124  3.9822732   3.98222517  3.98217712  3.98212908  3.98208103
#   3.98203298  3.98198492  3.98193686  3.9818888   3.98184074  3.98179267
#   3.9817446   3.98169654  3.98164847  3.98160039  3.98155232  3.98150425
#   3.98145618  3.9814081   3.98136003  3.98131195  3.98126388  3.9812158
#   3.98116773  3.98111965  3.98107157  3.9810235   3.98097542  3.98092735
#   3.98087927  3.98083921  3.98079113  3.98074306  3.98069498  3.98064691
#   3.98059883  3.98055076  3.98050269  3.98045462  3.98040655  3.98035848
#   3.98031041  3.98026234  3.98021427  3.9801662   3.98011814  3.98007007
#   3.98002201  3.97997394  3.97992588  3.97987782  3.97982976  3.9797817
#   3.97973364  3.97968559  3.97963753  3.97958948  3.97954142  3.97949337
#   3.97944532  3.97939727  3.97934922  3.97930117  3.97926113  3.97921309
#   3.97916504  3.979117    3.97906896  3.97902092  3.97897288  3.97892484
#   3.9788768   3.97882877  3.97878073  3.9787327   3.97868467  3.97863664
#   3.97858861  3.97854058  3.97849255  3.97844453  3.97839651  3.97834848
#   3.97830046  3.97825244  3.97820443  3.97815641  3.97810839  3.97806038
#   3.97801237  3.97796436  3.97791635  3.97786834  3.97782033  3.97777233
#   3.97772432  3.97767632  3.97763632  3.97758832  3.97754032  3.97749232
#   3.97744433  3.97739633  3.97734834  3.97730035  3.97725236  3.97720437
#   3.97715638  3.9771084   3.97706041  3.97701243  3.97696445  3.97691647
#   3.97686849  3.97682051  3.97677254  3.97672457  3.97667659  3.97662862
#   3.97658065  3.97653268  3.97648472  3.97643675  3.97638879  3.97634083
#   3.97629287  3.97624491  3.97619695  3.97614899  3.97610104  3.97606108
#   3.97601313  3.97596518  3.97591723  3.97586928  3.97582133  3.97577339
#   3.97572545  3.9756775   3.97562956  3.97558163  3.97553369  3.97548575
#   3.97543782  3.97538989  3.97534195  3.97529403  3.9752461   3.97519817
#   3.97515025  3.97510232  3.9750544   3.97500648  3.97495856  3.97491064
#   3.97486273  3.97481481  3.9747669   3.97471899  3.97467108  3.97462317
#   3.97457526]
# theory 12.67
# theory 3.94484121351
# [ 0.00993374  0.00992205  0.00991026  0.00989842  0.00988652  0.00987458
#   0.00986262  0.00985062  0.00983861  0.00982658  0.00981454  0.00980248
#   0.00979042  0.00977834  0.00976625  0.00975416  0.00974205  0.00972994
#   0.00971782  0.00970569  0.00969356  0.00968143  0.00966928  0.00965714
#   0.00964499  0.00963283  0.00962067  0.00960851  0.00959635  0.00958419
#   0.00957202  0.00955985  0.00954768  0.00953754  0.00952537  0.0095132
#   0.00950102  0.00948885  0.00947667  0.00946449  0.00945231  0.00944013
#   0.00942795  0.00941577  0.00940358  0.0093914   0.00937922  0.00936703
#   0.00935485  0.00934266  0.00933048  0.00931829  0.00930611  0.00929392
#   0.00928173  0.00926955  0.00925736  0.00924517  0.00923299  0.0092208
#   0.00920861  0.00919643  0.00918424  0.00917205  0.00915986  0.00914768
#   0.00913549  0.00912533  0.00911315  0.00910096  0.00908877  0.00907659
#   0.0090644   0.00905221  0.00904003  0.00902784  0.00901566  0.00900347
#   0.00899129  0.0089791   0.00896692  0.00895473  0.00894255  0.00893036
#   0.00891818  0.00890599  0.00889381  0.00888163  0.00886944  0.00885726
#   0.00884508  0.0088329   0.00882071  0.00880853  0.00879635  0.00878417
#   0.00877199  0.00875981  0.00874763  0.00873545  0.0087253   0.00871312
#   0.00870094  0.00868876  0.00867658  0.00866441  0.00865223  0.00864005
#   0.00862787  0.0086157   0.00860352  0.00859134  0.00857917  0.00856699
#   0.00855482  0.00854264  0.00853047  0.00851829  0.00850612  0.00849395
#   0.00848177  0.0084696   0.00845743  0.00844526  0.00843308  0.00842091
#   0.00840874  0.00839657  0.0083844   0.00837223  0.00836006  0.00834789
#   0.00833572  0.00832356  0.00831342  0.00830125  0.00828908  0.00827691
#   0.00826475  0.00825258  0.00824041  0.00822825  0.00821608  0.00820392
#   0.00819175  0.00817959  0.00816743  0.00815526  0.0081431   0.00813094
#   0.00811877  0.00810661  0.00809445  0.00808229  0.00807013  0.00805797
#   0.00804581  0.00803365  0.00802149  0.00800933  0.00799717  0.00798501
#   0.00797286  0.0079607   0.00794854  0.00793639  0.00792423  0.0079141
#   0.00790194  0.00788979  0.00787763  0.00786548  0.00785332  0.00784117
#   0.00782902  0.00781686  0.00780471  0.00779256  0.00778041  0.00776826
#   0.00775611  0.00774395  0.0077318   0.00771965  0.00770751  0.00769536
#   0.00768321  0.00767106  0.00765891  0.00764676  0.00763462  0.00762247
#   0.00761032  0.00759818  0.00758603  0.00757388  0.00756174  0.0075496
#   0.00753745]

# %%
plot_kappa(60, './z60bz0001')
timez2, colltimez2, kappaz2, kappaEHz2 = get_kappa_sim_theo('./z60bz0001', start_steps=199)
print(timez2,colltimez2,kappaz2,kappaEHz2)
print('theory '+str(heatflow.getKappaEH([0.0198],[60])[0][0]))
print('theory '+str(heatflow.getKappaEH([0.0198],[60])[1][0]))
print(abs(kappaEHz2-heatflow.getKappaEH([0.0198],[60])[1][0])/heatflow.getKappaEH([0.0198],[60])[1][0])
# Out:
# [ 59450.] [ 2434.35175012] [ 68.92607486] [ 12.57963856]
# theory 12.67
# theory 10.7328469974
# [ 0.17206912]

# %%
plot_kappa(60, './z60bz01')
timez2, colltimez2, kappaz2, kappaEHz2 = get_kappa_sim_theo('./z60bz01', start_steps=199)
print(timez2,colltimez2,kappaz2,kappaEHz2)
print('theory '+str(heatflow.getKappaEH([1.98],[60])[0][0]))
print('theory '+str(heatflow.getKappaEH([1.98],[60])[1][0]))
print(abs(kappaEHz2-heatflow.getKappaEH([1.98],[60])[1][0])/heatflow.getKappaEH([1.98],[60])[1][0])
# Out:
# [ 59450.] [ 2434.35175012] [ 63.14335433] [ 7.04390343]
# theory 12.67
# theory 0.251698305617
# [ 26.98550198]

# %%
plot_kappa(60, './z60bz01')
timez2, colltimez2, kappaz2, kappaEHz2 = get_kappa_sim_theo('./z60bz01', start_steps=199)
print(timez2,colltimez2,kappaz2,kappaEHz2)
print('theory '+str(heatflow.getKappaEH([1.98],[60])[0][0]))
print('theory '+str(heatflow.getKappaEH([1.98],[60])[1][0]))
print(abs(kappaEHz2-heatflow.getKappaEH([1.98],[60])[1][0])/heatflow.getKappaEH([1.98],[60])[1][0])
# Out:
# [ 59450.] [ 2427.32785299] [ 33.22730654] [ 7.0552634]
# theory 12.67
# theory 0.251698305617
# [ 27.03063527]

# %%
plot_kappa(60, './z60bz01')
timez2, colltimez2, kappaz2, kappaEHz2 = get_kappa_sim_theo('./z60bz01', start_steps=199)
print(timez2,colltimez2,kappaz2,kappaEHz2)
print('theory '+str(heatflow.getKappaEH([1.98],[60])[0][0]))
print('theory '+str(heatflow.getKappaEH([1.98],[60])[1][0]))
print(abs(kappaEHz2-heatflow.getKappaEH([1.98],[60])[1][0])/heatflow.getKappaEH([1.98],[60])[1][0])
# Out:
# [ 59450.] [ 2427.32785299] [ 33.22730654] [ 7.0552634]
# theory 12.67
# theory 0.251698305617
# [ 27.03063527]

# %%
plot_kappa(60, './z60bz01')
timez2, colltimez2, kappaz2, kappaEHz2 = get_kappa_sim_theo('./z60bz01', start_steps=199)
print(timez2,colltimez2,kappaz2,kappaEHz2)
print('theory '+str(heatflow.getKappaEH([1.98],[60])[0][0]))
print('theory '+str(heatflow.getKappaEH([1.98],[60])[1][0]))
print(abs(kappaEHz2-heatflow.getKappaEH([1.98],[60])[1][0])/heatflow.getKappaEH([1.98],[60])[1][0])
# Out:
# [ 59450.] [ 2427.32785299] [ 33.22730654] [ 7.0552634]
# theory 12.67
# theory 0.251698305617
# [ 27.03063527]

# %% [markdown]
# ## Obtain the theory and simulation heat-flow coefficient for different ionization state
#
# We use the heat-flow coefficient obtained from the last output from each simulation as the simulation results.

# %%
timez2, colltimez2, kappaz2, kappaEHz2 = get_kappa_sim_theo('./old-dirs/z2', start_steps=199)
timez2t, colltimez2t, kappaz2t, kappaEHz2t = get_kappa_sim_theo('./old-dirs/z2t', start_steps=199)

timez20, colltimez20, kappaz20, kappaEHz20 = get_kappa_sim_theo('./old-dirs/z20', start_steps=199)
timez20t, colltimez20t, kappaz20t, kappaEHz20t = get_kappa_sim_theo('./old-dirs/z20t', start_steps=199)

timez40, colltimez40, kappaz40, kappaEHz40 = get_kappa_sim_theo('./old-dirs/z40', start_steps=199)
timez40t, colltimez40t, kappaz40t, kappaEHz40t = get_kappa_sim_theo('./old-dirs/z40t', start_steps=199)

timez60, colltimez60, kappaz60, kappaEHz60 = get_kappa_sim_theo('./old-dirs/z60', start_steps=199)
timez60t, colltimez60t, kappaz60t, kappaEHz60t = get_kappa_sim_theo('./old-dirs/z60t', start_steps=199)


zlist = range(1, 70)
kappa_theo = [heatflow.getKappaEH([0],[z])[0][0] for z in zlist]

sim_zlist = [2, 2, 20, 20, 40, 40, 60, 60]
kappa_sim = [kappaz2t[-1], kappaz2[-1], kappaz20t[-1], kappaz20[-1], kappaz40t[-1], kappaz40[-1], kappaz60t[-1], kappaz60[-1]]

# %% [markdown]
# ### Plotting the heat-flow coefficients for simulations and theory
#
# The first plot shows the heat flow coefficient after 10 ps in a millimeter plasma for various ionization states.
#
# The second plot shows the relative differences between the theory and simulation results. Since we are using suboptimal $N_v$ value in these simulations, the differences are larger than they should be. If we use better resolution in momentum space ($N_v=256$ for example), both simulation results (with and without keeping all $f_l^m$ terms) would get closer to the theroy.

# %%
plt.plot(zlist, kappa_theo, label='Analytical')
plt.scatter(sim_zlist[1::2], kappa_sim[1::2], marker='x', color='red', label='OSHUN: all terms')
plt.scatter(sim_zlist[::2], kappa_sim[::2], marker='o', color='red', label='OSHUN: tri-diagonal terms')
plt.xlabel('ionization state')
plt.ylabel('$\kappa_\perp^c (nT\tau_{ei}/m_e)$')
plt.grid()
plt.legend()

err = [100*(ks-kappa_theo[z-1])/kappa_theo[z] for z, ks in zip(sim_zlist, kappa_sim)]
plt.figure()
plt.scatter(sim_zlist[1::2], err[1::2], marker='x', color='red', label='OSHUN: all terms')
plt.scatter(sim_zlist[::2], err[::2], marker='o', color='red', label='OSHUN: tri-diagonal terms')
plt.xlabel('ionization state')
plt.ylabel('relative error (%)')
plt.ylim([-6, 4])
plt.grid()
plt.legend()

# %% [markdown]
# ===========================================================================================

# %% [markdown]
# ## Heat-flow coefficient for different magnetizations
#
# Now we perform similar simulations in the presence of a constant external magnetic field in the $\hat{z}$ direction. OSHUN has the ability to impose an external magnetic field in the system. Using this feature, the plasma is held at the desired level of magnetization.
#
# The gyrofrequency has to be resolved in these simulations, meaning the time-step must be reduced as the magnetization ($\omega\tau$) increases.
#
# Again we use the heat-flow coefficient obtained from the last output from each simulation as the simulation results.

# %% [markdown]
# The following figure shows excellent agreement between the results from \textsc{oshun} and the calculation in Epperlein and Haines over a range of magnetizations, $\omega_c\tau_{ei} = 0.01,0.06,0.1,0.6,1,3$ for both Z=2 and Z=60. Here, $\omega_c$ is the gyrofrequency and $\tau_{ei}$ is the electron-ion collision frequency.

# %%
def get_Qx_sim(directory, total_steps=200, start_steps=1):
    nu_ei = np.mean(heatflow.pullcompoundData(directory,'nuei', 0)[-1])  
    simtime, realtime, axes, data_Qx = heatflow.pullData(directory,'Qx',0)
    time, Qx = [], []
    for ti in range(start_steps, total_steps):
        simtime, realtime, axes, data_Qx = heatflow.pullData(directory,'Qx',ti)
        time.append(simtime)
        Qx.append(np.max(data_Qx))
    time, Qx = np.array(time), np.array(Qx) 
    colltime = time * nu_ei
    return time, colltime, Qx
    
    
def plot_qx(Z, dir1, dir2, **kwargs):
    time, colltime, Qx1 = get_Qx_sim(dir1, **kwargs)
    time, colltime, Qx2 = get_Qx_sim(dir2, **kwargs)
    plt.plot(colltime, Qx1, colltime, Qx2)
    plt.ylabel('max($Q_x$)')
    plt.xlabel(r'Time ($\nu_{ei}^{-1}$)')
    plt.grid()
    plt.title('Z=' + str(Z))
#     plt.legend(['All terms', 'Tri-diagonal terms'])

#     plt.rc('font', size=16)
#     fig, ax1 = plt.subplots()
#     ax2 = ax1.twiny()
#     ax1.plot(time, Qx1)
# #     ax1.plot()
#     ax1.set_xlabel('Time ($\omega_0^{-1}$)')
#     ax2.plot(colltime, Qx2)
#     ax2.set_xlabel(r'Time ($\nu_{ei}^{-1}$)', wrap=False)
#     ax1.set_ylabel(')
# #     ax2.cla()
    
#     
#     ax1.grid()
    plt.show()

# %%
plot_qx(60, './', './')
plt.figure()
plot_qx(60, './Z60', './Z60')

# %%
plot_kappa(60, './')

# %%
time, axes, kappa, _ = heatflow.getcompoundxt('./','kappaEH',np.array(range(1, 200)))
kappa
# Out:
# array([ 10.950819  ,  10.95080688,  10.95079475,  10.95078243,
#         10.95077017,  10.95075776,  10.95074545,  10.950733  ,
#         10.95072066,  10.95070818,  10.95069582,  10.95068333,
#         10.95067096,  10.95065847,  10.95064609,  10.95063359,
#         10.95062121,  10.95060871,  10.95059633,  10.95058383,
#         10.95057145,  10.95055895,  10.95054658,  10.95053407,
#         10.9505217 ,  10.9505092 ,  10.95049683,  10.95048433,
#         10.95047196,  10.95045946,  10.95044709,  10.95043459,
#         10.95042222,  10.95040973,  10.95039736,  10.95038487,
#         10.95037251,  10.95036002,  10.95034765,  10.95033516,
#         10.9503228 ,  10.95031031,  10.95029795,  10.95028546,
#         10.9502731 ,  10.95026061,  10.95024825,  10.95023577,
#         10.95022341,  10.95021092,  10.95019857,  10.95018608,
#         10.95017373,  10.95016125,  10.95014889,  10.95013641,
#         10.95012405,  10.95011157,  10.95009922,  10.95008674,
#         10.95007439,  10.95006191,  10.95004956,  10.95003708,
#         10.95002473,  10.95001225,  10.9499999 ,  10.94998742,
#         10.94997507,  10.9499626 ,  10.94995025,  10.94993778,
#         10.94992543,  10.94991296,  10.94990061,  10.94988814,
#         10.94987579,  10.94986332,  10.94985097,  10.9498385 ,
#         10.94982616,  10.94981369,  10.94980135,  10.94978888,
#         10.94977653,  10.94976407,  10.94975172,  10.94973926,
#         10.94972692,  10.94971445,  10.94970211,  10.94968965,
#         10.94967731,  10.94966484,  10.9496525 ,  10.94964004,
#         10.9496277 ,  10.94961524,  10.9496029 ,  10.94959044,
#         10.9495781 ,  10.94956564,  10.94955331,  10.94954085,
#         10.94952851,  10.94951606,  10.94950372,  10.94949126,
#         10.94947893,  10.94946647,  10.94945414,  10.94944169,
#         10.94942935,  10.9494169 ,  10.94940457,  10.94939211,
#         10.94937978,  10.94936733,  10.949355  ,  10.94934255,
#         10.94933022,  10.94931777,  10.94930544,  10.94929299,
#         10.94928067,  10.94926821,  10.94925589,  10.94924344,
#         10.94923112,  10.94921867,  10.94920634,  10.9491939 ,
#         10.94918157,  10.94916913,  10.9491568 ,  10.94914436,
#         10.94913204,  10.94911959,  10.94910727,  10.94909483,
#         10.94908251,  10.94907006,  10.94905774,  10.9490453 ,
#         10.94903298,  10.94902054,  10.94900822,  10.94899578,
#         10.94898347,  10.94897103,  10.94895871,  10.94894627,
#         10.94893396,  10.94892152,  10.9489092 ,  10.94889677,
#         10.94888445,  10.94887202,  10.9488597 ,  10.94884727,
#         10.94883496,  10.94882252,  10.94881021,  10.94879778,
#         10.94878547,  10.94877303,  10.94876072,  10.94874829,
#         10.94873598,  10.94872355,  10.94871124,  10.94869881,
#         10.9486865 ,  10.94867407,  10.94866177,  10.94864934,
#         10.94863703,  10.9486246 ,  10.9486123 ,  10.94859987,
#         10.94858757,  10.94857514,  10.94856284,  10.94855041,
#         10.94853811,  10.94852568,  10.94851338,  10.94850096,
#         10.94848866,  10.94847623,  10.94846393,  10.94845151,
#         10.94843921,  10.94842679,  10.94841449,  10.94840207,
#         10.94838977,  10.94837735,  10.94836506])
